# %%
import os
import sys
import re
import time
import random
from collections import Counter
from string import punctuation
from operator import itemgetter

import numpy as np
import pandas as pd
import seaborn as sns # visualization
import matplotlib.pyplot as plt # visualization
# %matplotlib inline

import email
import statistics

import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import spacy

import emot
from wordcloud import WordCloud, STOPWORDS

# machine learning
from sklearn import cross_validation
from sklearn.model_selection import cross_val_score
from sklearn import svm
from sklearn.cross_validation import train_test_split
from sklearn import metrics
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import minmax_scale
from sklearn.metrics import accuracy_score
from sklearn import preprocessing
from sklearn.preprocessing import label_binarize
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.multiclass import OneVsRestClassifier

# %%
from extract_email_info import extract_email_info 
# function is writen in extract.py file
import features
# functions are writen in features.py file

# %%
nlp = spacy.load('en')

# %% [markdown]
# ## Collect data

# %%
# Read the data into a DataFrame
emails_df = pd.read_csv('emails.csv')
emails_df.head(1)
# Out:
#                     file                                            message
# 0  allen-p/_sent_mail/1.  Message-ID: <18782981.1075855378110.JavaMail.e...

# %% [markdown]
# ## Message analysis

# %% [markdown]
# ### Using Email Module to analysis email messages.
# - from Kaggle JayKrishna 's Kernel: Topic Modeling Enron Email Dataset.

# %%
# use small amount of data to try function
emails_df_test = emails_df

# %%
aem(emails_df_test)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Users/jingqin/venv3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'message'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-267-bf23731398d9> in <module>()
# ----> 1 aem(emails_df_test)
#
# /Users/jingqin/VU/python-for-text-analysis/Final_Assignment/enron_email/src/analysis_email_messages.py in aem(emails_df)
#      24 def aem(emails_df):
#      25     # Parse the emails into a list email objects
# ---> 26     messages = list(map(email.message_from_string, emails_df['message']))
#      27     emails_df.drop('message', axis=1, inplace=True)
#      28     # Get fields from parsed email objects
#
# /Users/jingqin/venv3/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2137             return self._getitem_multilevel(key)
#    2138         else:
# -> 2139             return self._getitem_column(key)
#    2140
#    2141     def _getitem_column(self, key):
#
# /Users/jingqin/venv3/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2144         # get column
#    2145         if self.columns.is_unique:
# -> 2146             return self._get_item_cache(key)
#    2147
#    2148         # duplicate columns & possible reduce dimensionality
#
# /Users/jingqin/venv3/lib/python3.6/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    1840         res = cache.get(item)
#    1841         if res is None:
# -> 1842             values = self._data.get(item)
#    1843             res = self._box_item_values(item, values)
#    1844             cache[item] = res
#
# /Users/jingqin/venv3/lib/python3.6/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    3841
#    3842             if not isna(item):
# -> 3843                 loc = self.items.get_loc(item)
#    3844             else:
#    3845                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# /Users/jingqin/venv3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
# -> 2527                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2528
#    2529         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'message'

# %% [markdown]
# ### To avoid repeat computation, store result dataframe to csv file.

# %%
# complete data after progress is stored in to an csv file.
emails_df.to_csv("email_csv.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-268-2b6d6ffa9801> in <module>()
#       1 # complete data after progress is stored in to an csv file.
# ----> 2 emails_df.to_csv("email_csv.csv", index=False)
#
# /Users/jingqin/venv3/lib/python3.6/site-packages/pandas/core/frame.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, tupleize_cols, date_format, doublequote, escapechar, decimal)
#    1522                                      doublequote=doublequote,
#    1523                                      escapechar=escapechar, decimal=decimal)
# -> 1524         formatter.save()
#    1525
#    1526         if path_or_buf is None:
#
# /Users/jingqin/venv3/lib/python3.6/site-packages/pandas/io/formats/format.py in save(self)
#    1650                 self.writer = UnicodeWriter(f, **writer_kwargs)
#    1651
# -> 1652             self._save()
#    1653
#    1654         finally:
#
# /Users/jingqin/venv3/lib/python3.6/site-packages/pandas/io/formats/format.py in _save(self)
#    1752                 break
#    1753
# -> 1754             self._save_chunk(start_i, end_i)
#    1755
#    1756     def _save_chunk(self, start_i, end_i):
#
# /Users/jingqin/venv3/lib/python3.6/site-packages/pandas/io/formats/format.py in _save_chunk(self, start_i, end_i)
#    1766                                   decimal=self.decimal,
#    1767                                   date_format=self.date_format,
# -> 1768                                   quoting=self.quoting)
#    1769
#    1770             for col_loc, col in zip(b.mgr_locs, d):
#
# /Users/jingqin/venv3/lib/python3.6/site-packages/pandas/core/internals.py in to_native_types(self, slicer, na_rep, quoting, **kwargs)
#     719         if slicer is not None:
#     720             values = values[:, slicer]
# --> 721         mask = isna(values)
#     722
#     723         if not self.is_object and not quoting:
#
# /Users/jingqin/venv3/lib/python3.6/site-packages/pandas/core/dtypes/missing.py in isna(obj)
#      43     pandas.isnull: alias of isna
#      44     """
# ---> 45     return _isna(obj)
#      46
#      47
#
# /Users/jingqin/venv3/lib/python3.6/site-packages/pandas/core/dtypes/missing.py in _isna_new(obj)
#      56         raise NotImplementedError("isna is not defined for MultiIndex")
#      57     elif isinstance(obj, (ABCSeries, np.ndarray, ABCIndexClass)):
# ---> 58         return _isna_ndarraylike(obj)
#      59     elif isinstance(obj, ABCGeneric):
#      60         return obj._constructor(obj._data.isna(func=isna))
#
# /Users/jingqin/venv3/lib/python3.6/site-packages/pandas/core/dtypes/missing.py in _isna_ndarraylike(obj)
#     144             else:
#     145                 result = np.empty(shape, dtype=bool)
# --> 146                 vec = lib.isnaobj(values.ravel())
#     147                 result[...] = vec.reshape(shape)
#     148
#
# KeyboardInterrupt:

# %%
email_tmp = pd.read_csv('../email_csv.csv')
email_tmp.head()
# Out:
#                        file                                     Message-ID  \
# 0     allen-p/_sent_mail/1.  <18782981.1075855378110.JavaMail.evans@thyme>
# 1    allen-p/_sent_mail/10.  <15464986.1075855378456.JavaMail.evans@thyme>
# 2   allen-p/_sent_mail/100.  <24216240.1075855687451.JavaMail.evans@thyme>
# 3  allen-p/_sent_mail/1000.  <13505866.1075863688222.JavaMail.evans@thyme>
# 4  allen-p/_sent_mail/1001.  <30922949.1075863688243.JavaMail.evans@thyme>
#
#                                     Date  \
# 0  Mon, 14 May 2001 16:39:00 -0700 (PDT)
# 1   Fri, 4 May 2001 13:51:00 -0700 (PDT)
# 2  Wed, 18 Oct 2000 03:00:00 -0700 (PDT)
# 3  Mon, 23 Oct 2000 06:13:00 -0700 (PDT)
# 4  Thu, 31 Aug 2000 05:07:00 -0700 (PDT)
#
#                                      From  \
# 0  frozenset({'phillip.allen@enron.com'})
# 1  frozenset({'phillip.allen@enron.com'})
# 2  frozenset({'phillip.allen@enron.com'})
# 3  frozenset({'phillip.allen@enron.com'})
# 4  frozenset({'phillip.allen@enron.com'})
#
#                                        To    Subject  Mime-Version  \
# 0     frozenset({'tim.belden@enron.com'})        NaN           1.0
# 1  frozenset({'john.lavorato@enron.com'})        Re:           1.0
# 2   frozenset({'leah.arsdall@enron.com'})   Re: test           1.0
# 3    frozenset({'randall.gay@enron.com'})        NaN           1.0
# 4     frozenset({'greg.piper@enron.com'})  Re: Hello           1.0
#
#                    Content-Type Content-Transfer-Encoding           X-From  \
# 0  text/plain; charset=us-ascii                      7bit  Phillip K Allen
# 1  text/plain; charset=us-ascii                      7bit  Phillip K Allen
# 2  text/plain; charset=us-ascii                      7bit  Phillip K Allen
# 3  text/plain; charset=us-ascii                      7bit  Phillip K Allen
# 4  text/plain; charset=us-ascii                      7bit  Phillip K Allen
#
#                                                 X-To X-cc X-bcc  \
# 0           Tim Belden <Tim Belden/Enron@EnronXGate>  NaN   NaN
# 1  John J Lavorato <John J Lavorato/ENRON@enronXg...  NaN   NaN
# 2                                   Leah Van Arsdall  NaN   NaN
# 3                                      Randall L Gay  NaN   NaN
# 4                                         Greg Piper  NaN   NaN
#
#                                             X-Folder X-Origin  \
# 0  \Phillip_Allen_Jan2002_1\Allen, Phillip K.\'Se...  Allen-P
# 1  \Phillip_Allen_Jan2002_1\Allen, Phillip K.\'Se...  Allen-P
# 2    \Phillip_Allen_Dec2000\Notes Folders\'sent mail  Allen-P
# 3    \Phillip_Allen_Dec2000\Notes Folders\'sent mail  Allen-P
# 4    \Phillip_Allen_Dec2000\Notes Folders\'sent mail  Allen-P
#
#                     X-FileName  \
# 0  pallen (Non-Privileged).pst
# 1  pallen (Non-Privileged).pst
# 2                   pallen.nsf
# 3                   pallen.nsf
# 4                   pallen.nsf
#
#                                              content     user
# 0                          Here is our forecast\n\n   allen-p
# 1  Traveling to have a business meeting takes the...  allen-p
# 2                     test successful.  way to go!!!  allen-p
# 3  Randy,\n\n Can you send me a schedule of the s...  allen-p
# 4                Let's shoot for Tuesday at 11:45.    allen-p

# %%
email_tmp.shape
# Out:
# (517401, 18)

# %%
emails_df = email_tmp

# %% [markdown]
# ## Understand Data

# %% [markdown]
# #### Check how data are distributed

# %%
emails_df["user"].describe()
# Out:
# count         517401
# unique           150
# top       kaminski-v
# freq           28465
# Name: user, dtype: object

# %%
emails_df.groupby(['user']).count()['From']
# Out:
# user
# allen-p            3034
# arnold-j           4898
# arora-h             654
# badeer-r            877
# bailey-s            478
# bass-e             7823
# baughman-d         2760
# beck-s            11830
# benson-r            767
# blair-l            3415
# brawner-s          1026
# buy-r              2429
# campbell-l         6490
# carson-m           1400
# cash-m             2969
# causholli-m         943
# corman-s           2025
# crandell-s          519
# cuilla-m           1029
# dasovich-j        28234
# davis-d            2249
# dean-c             2429
# delainey-d         3566
# derrick-j          1766
# dickson-s           395
# donoho-l           1045
# donohoe-t          1015
# dorland-c          2127
# ermis-f            1230
# farmer-d          13032
#                   ...
# smith-m            1642
# solberg-g          1081
# south-s             248
# staab-t             621
# stclair-c          3030
# steffes-j          3331
# stepenovitch-j     1227
# stokley-c          1252
# storey-g           1027
# sturm-f            1169
# swerzbin-m          355
# symes-k           10827
# taylor-m          13875
# tholt-j            1885
# thomas-p           1293
# townsend-j          646
# tycholiz-b         1219
# ward-k             2611
# watson-k           2950
# weldon-c           1566
# whalley-g          1878
# whalley-l          3335
# white-s            3272
# whitt-m             807
# williams-j         1213
# williams-w3        3440
# wolfe-j            1587
# ybarbo-p           1291
# zipper-a           1563
# zufferli-j          557
# Name: From, Length: 150, dtype: int64

# %%
# have a look at how many email address are used by one user 
emails_df.loc[emails_df['user'] == "dasovich-j", 'From'].unique()
# Out:
# array(["frozenset({'dhunter@smithandkempton.com'})",
#        "frozenset({'perfmgmt@enron.com'})",
#        "frozenset({'paul.kaufman@enron.com'})", ...,
#        "frozenset({'chris.dcouto@novellus.com'})",
#        "frozenset({'dgrueneich@gralegal.com'})",
#        "frozenset({'pds6@pge.com'})"], dtype=object)

# %% [markdown]
# #### check the distribution of the number of emails

# %%
sns.countplot(x='user', data=emails_df, order = emails_df['user'].value_counts().index)

# %%
email_count = emails_df['user'].value_counts()
ten_thousand_plus = email_count[email_count > 10000]
print (len(ten_thousand_plus))
len(emails_df.groupby('user').filter(lambda x: len(x) >10000))
# Out:
# 12
# 216723

# %% [markdown]
# ####  527372 emails from 27980 email address and from 150 people, there are 12 people send over 10000 emails, I will only work on those data(216723 emails in total). "user" can be used as the golden standard,  "content" will be analysed below, rest columns are not needed.

# %%
emails_df_10000 = emails_df.groupby('user').filter(lambda x: len(x) >10000)

# %%
print(emails_df_10000.shape)
# Out:
# (216723, 18)

# %% [markdown]
# ## Basic Natural Language Processing tasks
# ### Four basic task is performed below with one sample from data

# %% [markdown]
# ### Sentence splitting

# %%
test_sentences = emails_df_10000['content'].iloc[12]

doc = nlp(test_sentences)

# %%
sents = []
for span in doc.sents:
    sent = ''.join(doc[i].string for i in range(span.start, span.end)).strip()
    sents.append(sent)
print(len(sents),"sentences")
for sentence in sents:
    print(sentence,len(sentence.split()))
# Out:
# 17 sentences
# Jeff, thanks for taking care of this for Fred. 9
# --Sally
#
#
#
#
# Jeffrey C Gossett 4
# 01/10/2001 1
# 11:39 AM 2
# To: 1
# Timothy M Norton/HOU/ECT@ECT, Matthew Condon/NA/Enron@ENRON 5
# , Tracy
# Beardmore/NA/Enron@Enron, Joyce Kuo/NA/Enron@Enron, Stewart 6
# Range/NA/Enron@ENRON, John Swinney/HOU/ECT@ECT, Michelle
# Nelson/Corp/Enron@ENRON, Jeremy Mills/Corp/ 7
# Enron@ENRON, John D
# Postlethwaite/CAL/ECT@ECT, Casey Evans/Corp/Enron@Enron, Valarie
# Sabo/PDX/ECT@ECT, Kam Keiser/HOU/ECT@ECT, Darron C Giron/HOU/ECT@ECT, David
# Baumbach/HOU/ECT@ECT, Errol McLaughlin/Corp/Enron@ENRON, Phillip M
# Love/HOU/ECT@ECT, Kathy Reeves/CAL/ECT@ECT, Brian Gillis/CAL/ECT@ECT
# cc: Michelle Bruce/HOU/ECT@ECT, Stacey W White/HOU/ECT@ECT, Sheila 31
# Glover/HOU/ECT@ECT, Sally Beck/HOU/ECT@ECT
# Subject: 4
# Lagrasta Origination 2
# I appreciate everyone's help in making sure that all the information for
# Lagrasta's originated is deals is accurate. 18
# He is now receiving a daily
# report with all originated deals. 11
# He has also asked that we give him the data on the deals that his group has
# done that do not have origination. 23
# Therefore,  going forward we will need to
# put all deals for Lagrasta's group into the origination file. 17
# Meaning,  if
# his group does a deal where no origination is granted,  you will need to put
# all the relevant information into the origination file and just put a $0 for
# the Origination granted on the report. 37
# Thanks so much for your help. 6

# %% [markdown]
# ### Tokenization POS-tagging Lemmatization

# %%
for token in doc:
    print(token.orth_, token.pos_, token.lemma_)
# Out:
# Jeff PROPN jeff
# , PUNCT ,
# thanks NOUN thank
# for ADP for
# taking VERB take
# care NOUN care
# of ADP of
# this DET this
# for ADP for
# Fred PROPN fred
# . PUNCT .
# --Sally ADV --sally
#
#
#
#
#
#  SPACE
#
#
#
#
#
# Jeffrey PROPN jeffrey
# C PROPN c
# Gossett PROPN gossett
#
#  SPACE
#
# 01/10/2001 NUM 01/10/2001
# 11:39 NUM 11:39
# AM NOUN am
#
#  SPACE
#
# To ADP to
# : PUNCT :
# Timothy PROPN timothy
# M PROPN m
# Norton PROPN norton
# / SYM /
# HOU PROPN hou
# / SYM /
# ECT@ECT PROPN ect@ect
# , PUNCT ,
# Matthew PROPN matthew
# Condon PROPN condon
# / SYM /
# NA PROPN na
# / SYM /
# Enron@ENRON PROPN enron@enron
# , PUNCT ,
# Tracy PROPN tracy
#
#  SPACE
#
# Beardmore PROPN beardmore
# / SYM /
# NA PROPN na
# / SYM /
# Enron@Enron PROPN enron@enron
# , PUNCT ,
# Joyce PROPN joyce
# Kuo PROPN kuo
# / SYM /
# NA PROPN na
# / SYM /
# Enron@Enron PROPN enron@enron
# , PUNCT ,
# Stewart PROPN stewart
#
#  SPACE
#
# Range PROPN range
# / SYM /
# NA PROPN na
# / SYM /
# Enron@ENRON PROPN enron@enron
# , PUNCT ,
# John PROPN john
# Swinney PROPN swinney
# / SYM /
# HOU PROPN hou
# / SYM /
# ECT@ECT PROPN ect@ect
# , PUNCT ,
# Michelle PROPN michelle
#
#  SPACE
#
# Nelson PROPN nelson
# / SYM /
# Corp PROPN corp
# / SYM /
# Enron@ENRON PROPN enron@enron
# , PUNCT ,
# Jeremy PROPN jeremy
# Mills PROPN mills
# / SYM /
# Corp PROPN corp
# / SYM /
# Enron@ENRON PROPN enron@enron
# , PUNCT ,
# John PROPN john
# D PROPN d
#
#  SPACE
#
# Postlethwaite PROPN postlethwaite
# / SYM /
# CAL PROPN cal
# / SYM /
# ECT@ECT PROPN ect@ect
# , PUNCT ,
# Casey PROPN casey
# Evans PROPN evans
# / SYM /
# Corp PROPN corp
# / SYM /
# Enron@Enron PROPN enron@enron
# , PUNCT ,
# Valarie PROPN valarie
#
#  SPACE
#
# Sabo PROPN sabo
# / SYM /
# PDX PROPN pdx
# / SYM /
# ECT@ECT PROPN ect@ect
# , PUNCT ,
# Kam PROPN kam
# Keiser PROPN keiser
# / SYM /
# HOU PROPN hou
# / SYM /
# ECT@ECT PROPN ect@ect
# , PUNCT ,
# Darron PROPN darron
# C PROPN c
# Giron PROPN giron
# / SYM /
# HOU PROPN hou
# / SYM /
# ECT@ECT PROPN ect@ect
# , PUNCT ,
# David PROPN david
#
#  SPACE
#
# Baumbach PROPN baumbach
# / SYM /
# HOU PROPN hou
# / SYM /
# ECT@ECT PROPN ect@ect
# , PUNCT ,
# Errol PROPN errol
# McLaughlin PROPN mclaughlin
# / SYM /
# Corp PROPN corp
# / SYM /
# Enron@ENRON PROPN enron@enron
# , PUNCT ,
# Phillip PROPN phillip
# M PROPN m
#
#  SPACE
#
# Love PROPN love
# / SYM /
# HOU PROPN hou
# / SYM /
# ECT@ECT PROPN ect@ect
# , PUNCT ,
# Kathy PROPN kathy
# Reeves PROPN reeves
# / SYM /
# CAL PROPN cal
# / SYM /
# ECT@ECT PROPN ect@ect
# , PUNCT ,
# Brian PROPN brian
# Gillis PROPN gillis
# / SYM /
# CAL PROPN cal
# / SYM /
# ECT@ECT PROPN ect@ect
#
#  SPACE
#
# cc NOUN cc
# : PUNCT :
# Michelle PROPN michelle
# Bruce PROPN bruce
# / SYM /
# HOU PROPN hou
# / SYM /
# ECT@ECT PROPN ect@ect
# , PUNCT ,
# Stacey PROPN stacey
# W PROPN w
# White PROPN white
# / SYM /
# HOU PROPN hou
# / SYM /
# ECT@ECT PROPN ect@ect
# , PUNCT ,
# Sheila PROPN sheila
#
#  SPACE
#
# Glover PROPN glover
# / SYM /
# HOU PROPN hou
# / SYM /
# ECT@ECT PROPN ect@ect
# , PUNCT ,
# Sally PROPN sally
# Beck PROPN beck
# / SYM /
# HOU PROPN hou
# / SYM /
# ECT@ECT PROPN ect@ect
#
#  SPACE
#
# Subject PROPN subject
# : PUNCT :
# Lagrasta PROPN lagrasta
# Origination PROPN origination
#
#
#   SPACE
#
#
# I PRON -PRON-
# appreciate VERB appreciate
# everyone NOUN everyone
# 's PART 's
# help NOUN help
# in ADP in
# making VERB make
# sure ADJ sure
# that ADP that
# all ADJ all
# the DET the
# information NOUN information
# for ADP for
#
#  SPACE
#
# Lagrasta PROPN lagrasta
# 's PART 's
# originated NOUN originated
# is VERB be
# deals NOUN deal
# is VERB be
# accurate ADJ accurate
# . PUNCT .
#   SPACE
# He PRON -PRON-
# is VERB be
# now ADV now
# receiving VERB receive
# a DET a
# daily ADJ daily
#
#  SPACE
#
# report NOUN report
# with ADP with
# all DET all
# originated ADJ originated
# deals NOUN deal
# . PUNCT .
#
#
#   SPACE
#
#
# He PRON -PRON-
# has VERB have
# also ADV also
# asked VERB ask
# that ADP that
# we PRON -PRON-
# give VERB give
# him PRON -PRON-
# the DET the
# data NOUN datum
# on ADP on
# the DET the
# deals NOUN deal
# that ADJ that
# his ADJ -PRON-
# group NOUN group
# has VERB have
#
#  SPACE
#
# done VERB do
# that ADJ that
# do VERB do
# not ADV not
# have VERB have
# origination NOUN origination
# . PUNCT .
#   SPACE
# Therefore ADV therefore
# , PUNCT ,
#   SPACE
# going VERB go
# forward ADV forward
# we PRON -PRON-
# will VERB will
# need VERB need
# to PART to
#
#  SPACE
#
# put VERB put
# all DET all
# deals NOUN deal
# for ADP for
# Lagrasta PROPN lagrasta
# 's PART 's
# group NOUN group
# into ADP into
# the DET the
# origination NOUN origination
# file NOUN file
# . PUNCT .
#   SPACE
# Meaning PROPN meaning
# , PUNCT ,
#   SPACE
# if ADP if
#
#  SPACE
#
# his ADJ -PRON-
# group NOUN group
# does VERB do
# a DET a
# deal NOUN deal
# where ADV where
# no DET no
# origination NOUN origination
# is VERB be
# granted VERB grant
# , PUNCT ,
#   SPACE
# you PRON -PRON-
# will VERB will
# need VERB need
# to PART to
# put VERB put
#
#  SPACE
#
# all ADJ all
# the DET the
# relevant ADJ relevant
# information NOUN information
# into ADP into
# the DET the
# origination NOUN origination
# file NOUN file
# and CCONJ and
# just ADV just
# put VERB put
# a DET a
# $ SYM $
# 0 NUM 0
# for ADP for
#
#  SPACE
#
# the DET the
# Origination PROPN origination
# granted VERB grant
# on ADP on
# the DET the
# report NOUN report
# . PUNCT .
#   SPACE
# Thanks NOUN thank
# so ADV so
# much ADV much
# for ADP for
# your ADJ -PRON-
# help NOUN help
# . PUNCT .
#
#
#  SPACE

# %% [markdown]
# ### Named Entity Recognition

# %%
i = 0
for token in doc:
    i +=1
    print(i, token.orth_, token.ent_type_ if token.ent_type_ != "" else "(not an entity)")

print("-------------- entities only ---------------")
ents = list(doc.ents)
for entity in ents:
    print(entity.label, entity.label_, ' '.join(t.orth_ for t in entity))
# Out:
# 1 Jeff PERSON
# 2 , (not an entity)
# 3 thanks (not an entity)
# 4 for (not an entity)
# 5 taking (not an entity)
# 6 care (not an entity)
# 7 of (not an entity)
# 8 this (not an entity)
# 9 for (not an entity)
# 10 Fred (not an entity)
# 11 . (not an entity)
# 12 --Sally (not an entity)
# 13
#
#
#
#
#  ORG
# 14 Jeffrey (not an entity)
# 15 C (not an entity)
# 16 Gossett (not an entity)
# 17
#  (not an entity)
# 18 01/10/2001 (not an entity)
# 19 11:39 (not an entity)
# 20 AM (not an entity)
# 21
#  GPE
# 22 To (not an entity)
# 23 : (not an entity)
# 24 Timothy PERSON
# 25 M PERSON
# 26 Norton PERSON
# 27 / (not an entity)
# 28 HOU ORG
# 29 / (not an entity)
# 30 ECT@ECT (not an entity)
# 31 , (not an entity)
# 32 Matthew PERSON
# 33 Condon PERSON
# 34 / (not an entity)
# 35 NA ORG
# 36 / ORG
# 37 Enron@ENRON ORG
# 38 , (not an entity)
# 39 Tracy ORG
# 40
#  ORG
# 41 Beardmore ORG
# 42 / ORG
# 43 NA ORG
# 44 / ORG
# 45 Enron@Enron ORG
# 46 , (not an entity)
# 47 Joyce PERSON
# 48 Kuo PERSON
# 49 / PERSON
# 50 NA PERSON
# 51 / PERSON
# 52 Enron@Enron PERSON
# 53 , (not an entity)
# 54 Stewart ORG
# 55
#  ORG
# 56 Range (not an entity)
# 57 / (not an entity)
# 58 NA ORG
# 59 / ORG
# 60 Enron@ENRON ORG
# 61 , (not an entity)
# 62 John PERSON
# 63 Swinney PERSON
# 64 / (not an entity)
# 65 HOU ORG
# 66 / (not an entity)
# 67 ECT@ECT (not an entity)
# 68 , (not an entity)
# 69 Michelle PERSON
# 70
#  PERSON
# 71 Nelson PERSON
# 72 / (not an entity)
# 73 Corp (not an entity)
# 74 / (not an entity)
# 75 Enron@ENRON (not an entity)
# 76 , (not an entity)
# 77 Jeremy ORG
# 78 Mills ORG
# 79 / ORG
# 80 Corp ORG
# 81 / ORG
# 82 Enron@ENRON (not an entity)
# 83 , (not an entity)
# 84 John PERSON
# 85 D PERSON
# 86
#  PERSON
# 87 Postlethwaite ORG
# 88 / ORG
# 89 CAL ORG
# 90 / (not an entity)
# 91 ECT@ECT (not an entity)
# 92 , (not an entity)
# 93 Casey ORG
# 94 Evans ORG
# 95 / ORG
# 96 Corp ORG
# 97 / ORG
# 98 Enron@Enron ORG
# 99 , (not an entity)
# 100 Valarie ORG
# 101
#  ORG
# 102 Sabo ORG
# 103 / ORG
# 104 PDX ORG
# 105 / (not an entity)
# 106 ECT@ECT (not an entity)
# 107 , (not an entity)
# 108 Kam PERSON
# 109 Keiser PERSON
# 110 / (not an entity)
# 111 HOU ORG
# 112 / (not an entity)
# 113 ECT@ECT (not an entity)
# 114 , (not an entity)
# 115 Darron ORG
# 116 C ORG
# 117 Giron ORG
# 118 / ORG
# 119 HOU ORG
# 120 / (not an entity)
# 121 ECT@ECT (not an entity)
# 122 , (not an entity)
# 123 David PERSON
# 124
#  PERSON
# 125 Baumbach (not an entity)
# 126 / (not an entity)
# 127 HOU (not an entity)
# 128 / (not an entity)
# 129 ECT@ECT (not an entity)
# 130 , (not an entity)
# 131 Errol PERSON
# 132 McLaughlin PERSON
# 133 / ORG
# 134 Corp ORG
# 135 / ORG
# 136 Enron@ENRON ORG
# 137 , (not an entity)
# 138 Phillip ORG
# 139 M ORG
# 140
#  ORG
# 141 Love ORG
# 142 / ORG
# 143 HOU ORG
# 144 / (not an entity)
# 145 ECT@ECT (not an entity)
# 146 , (not an entity)
# 147 Kathy PERSON
# 148 Reeves PERSON
# 149 / PERSON
# 150 CAL PERSON
# 151 / (not an entity)
# 152 ECT@ECT (not an entity)
# 153 , (not an entity)
# 154 Brian PERSON
# 155 Gillis PERSON
# 156 / (not an entity)
# 157 CAL ORG
# 158 / ORG
# 159 ECT@ECT ORG
# 160
#  ORG
# 161 cc (not an entity)
# 162 : (not an entity)
# 163 Michelle PERSON
# 164 Bruce PERSON
# 165 / (not an entity)
# 166 HOU ORG
# 167 / (not an entity)
# 168 ECT@ECT (not an entity)
# 169 , (not an entity)
# 170 Stacey PERSON
# 171 W PERSON
# 172 White (not an entity)
# 173 / (not an entity)
# 174 HOU ORG
# 175 / (not an entity)
# 176 ECT@ECT (not an entity)
# 177 , (not an entity)
# 178 Sheila ORG
# 179
#  ORG
# 180 Glover (not an entity)
# 181 / (not an entity)
# 182 HOU (not an entity)
# 183 / (not an entity)
# 184 ECT@ECT (not an entity)
# 185 , (not an entity)
# 186 Sally PERSON
# 187 Beck PERSON
# 188 / (not an entity)
# 189 HOU ORG
# 190 / ORG
# 191 ECT@ECT ORG
# 192
#  ORG
# 193 Subject ORG
# 194 : (not an entity)
# 195 Lagrasta ORG
# 196 Origination ORG
# 197
#
#   (not an entity)
# 198 I (not an entity)
# 199 appreciate (not an entity)
# 200 everyone (not an entity)
# 201 's (not an entity)
# 202 help (not an entity)
# 203 in (not an entity)
# 204 making (not an entity)
# 205 sure (not an entity)
# 206 that (not an entity)
# 207 all (not an entity)
# 208 the (not an entity)
# 209 information (not an entity)
# 210 for (not an entity)
# 211
#  ORG
# 212 Lagrasta ORG
# 213 's ORG
# 214 originated (not an entity)
# 215 is (not an entity)
# 216 deals (not an entity)
# 217 is (not an entity)
# 218 accurate (not an entity)
# 219 . (not an entity)
# 220   (not an entity)
# 221 He (not an entity)
# 222 is (not an entity)
# 223 now (not an entity)
# 224 receiving (not an entity)
# 225 a (not an entity)
# 226 daily DATE
# 227
#  GPE
# 228 report (not an entity)
# 229 with (not an entity)
# 230 all (not an entity)
# 231 originated (not an entity)
# 232 deals (not an entity)
# 233 . (not an entity)
# 234
#
#   (not an entity)
# 235 He (not an entity)
# 236 has (not an entity)
# 237 also (not an entity)
# 238 asked (not an entity)
# 239 that (not an entity)
# 240 we (not an entity)
# 241 give (not an entity)
# 242 him (not an entity)
# 243 the (not an entity)
# 244 data (not an entity)
# 245 on (not an entity)
# 246 the (not an entity)
# 247 deals (not an entity)
# 248 that (not an entity)
# 249 his (not an entity)
# 250 group (not an entity)
# 251 has (not an entity)
# 252
#  GPE
# 253 done (not an entity)
# 254 that (not an entity)
# 255 do (not an entity)
# 256 not (not an entity)
# 257 have (not an entity)
# 258 origination (not an entity)
# 259 . (not an entity)
# 260   (not an entity)
# 261 Therefore (not an entity)
# 262 , (not an entity)
# 263   (not an entity)
# 264 going (not an entity)
# 265 forward (not an entity)
# 266 we (not an entity)
# 267 will (not an entity)
# 268 need (not an entity)
# 269 to (not an entity)
# 270
#  GPE
# 271 put (not an entity)
# 272 all (not an entity)
# 273 deals (not an entity)
# 274 for (not an entity)
# 275 Lagrasta ORG
# 276 's (not an entity)
# 277 group (not an entity)
# 278 into (not an entity)
# 279 the (not an entity)
# 280 origination (not an entity)
# 281 file (not an entity)
# 282 . (not an entity)
# 283   ORG
# 284 Meaning (not an entity)
# 285 , (not an entity)
# 286   ORG
# 287 if (not an entity)
# 288
#  GPE
# 289 his (not an entity)
# 290 group (not an entity)
# 291 does (not an entity)
# 292 a (not an entity)
# 293 deal (not an entity)
# 294 where (not an entity)
# 295 no (not an entity)
# 296 origination (not an entity)
# 297 is (not an entity)
# 298 granted (not an entity)
# 299 , (not an entity)
# 300   NORP
# 301 you (not an entity)
# 302 will (not an entity)
# 303 need (not an entity)
# 304 to (not an entity)
# 305 put (not an entity)
# 306
#  GPE
# 307 all (not an entity)
# 308 the (not an entity)
# 309 relevant (not an entity)
# 310 information (not an entity)
# 311 into (not an entity)
# 312 the (not an entity)
# 313 origination (not an entity)
# 314 file (not an entity)
# 315 and (not an entity)
# 316 just (not an entity)
# 317 put (not an entity)
# 318 a (not an entity)
# 319 $ (not an entity)
# 320 0 MONEY
# 321 for (not an entity)
# 322
#  ORG
# 323 the ORG
# 324 Origination ORG
# 325 granted (not an entity)
# 326 on (not an entity)
# 327 the (not an entity)
# 328 report (not an entity)
# 329 . (not an entity)
# 330   (not an entity)
# 331 Thanks (not an entity)
# 332 so (not an entity)
# 333 much (not an entity)
# 334 for (not an entity)
# 335 your (not an entity)
# 336 help (not an entity)
# 337 . (not an entity)
# 338
#
#  (not an entity)
# -------------- entities only ---------------
# 378 PERSON Jeff
# 381 ORG
#
#
#
#
#
# 382 GPE
#
# 378 PERSON Timothy M Norton
# 381 ORG HOU
# 378 PERSON Matthew Condon
# 381 ORG NA / Enron@ENRON
# 381 ORG Tracy
#  Beardmore / NA / Enron@Enron
# 378 PERSON Joyce Kuo / NA / Enron@Enron
# 381 ORG Stewart
#
# 381 ORG NA / Enron@ENRON
# 378 PERSON John Swinney
# 381 ORG HOU
# 378 PERSON Michelle
#  Nelson
# 381 ORG Jeremy Mills / Corp /
# 378 PERSON John D
#
# 381 ORG Postlethwaite / CAL
# 381 ORG Casey Evans / Corp / Enron@Enron
# 381 ORG Valarie
#  Sabo / PDX
# 378 PERSON Kam Keiser
# 381 ORG HOU
# 381 ORG Darron C Giron / HOU
# 378 PERSON David
#
# 378 PERSON Errol McLaughlin
# 381 ORG / Corp / Enron@ENRON
# 381 ORG Phillip M
#  Love / HOU
# 378 PERSON Kathy Reeves / CAL
# 378 PERSON Brian Gillis
# 381 ORG CAL / ECT@ECT
#
# 378 PERSON Michelle Bruce
# 381 ORG HOU
# 378 PERSON Stacey W
# 381 ORG HOU
# 381 ORG Sheila
#
# 378 PERSON Sally Beck
# 381 ORG HOU / ECT@ECT
#  Subject
# 381 ORG Lagrasta Origination
# 381 ORG
#  Lagrasta 's
# 388 DATE daily
# 382 GPE
#
# 382 GPE
#
# 382 GPE
#
# 381 ORG Lagrasta
# 381 ORG
# 381 ORG
# 382 GPE
#
# 379 NORP
# 382 GPE
#
# 391 MONEY 0
# 381 ORG
#  the Origination

# %% [markdown]
# ## features.py extract statistics (features) from files, will be used below

# %% [markdown]
# ## Store the computed statistics in a useful format

# %%
df = emails_df_10000[["Message-ID", "content", "user"]]

# %%
# randomly select 1000 sample email for each author.
df_1000 = df.groupby('user').apply(lambda df: df.sample(1000))

# %%
df_1000[990:1010]
# Out:
#                                                      Message-ID  \
# user
# beck-s     29795   <9303487.1075855881139.JavaMail.evans@thyme>
#            28933  <18089627.1075840357688.JavaMail.evans@thyme>
#            24495   <3573258.1075855760511.JavaMail.evans@thyme>
#            31891  <16472031.1075856073462.JavaMail.evans@thyme>
#            23954  <26638511.1075855951842.JavaMail.evans@thyme>
#            20799  <22810923.1075855918680.JavaMail.evans@thyme>
#            25823  <22088940.1075855838220.JavaMail.evans@thyme>
#            25812  <21422769.1075855837981.JavaMail.evans@thyme>
#            24463  <10825386.1075855759636.JavaMail.evans@thyme>
#            27931  <14760505.1075849834963.JavaMail.evans@thyme>
# dasovich-j 78414  <20757789.1075852610151.JavaMail.evans@thyme>
#            73641  <10671031.1075843178723.JavaMail.evans@thyme>
#            61834   <8482238.1075849319188.JavaMail.evans@thyme>
#            65347  <10228152.1075843318784.JavaMail.evans@thyme>
#            60289   <1308910.1075842996553.JavaMail.evans@thyme>
#            57037   <7677076.1075843440962.JavaMail.evans@thyme>
#            67670   <8925062.1075861469521.JavaMail.evans@thyme>
#            78617    <147108.1075859202794.JavaMail.evans@thyme>
#            81906   <9828008.1075843869133.JavaMail.evans@thyme>
#            64759  <31456369.1075842951022.JavaMail.evans@thyme>
#
#                                                             content  \
# user
# beck-s     29795  http://livelink.enron.co.uk/LiveLink/LiveLink....
#            28933  Sally,\n\nPlease see the attached file for an ...
#            24495  Very belated reply - I am cleaning up old e:ma...
#            31891  Per my memo below, please enroll Brenda Herod,...
#            23954  Thanks for doing this.  I plan to come to Lond...
#            20799     Wow - thanks for copying me on these.  --Sally
#            25823  ---------------------- Forwarded by Esther Ger...
#            25812  Tonight Kris and I met with the SAP team about...
#            24463  Call we talk about this some time soon.\n\ntha...
#            27931  Rick Buy informed us this morning that the BOD...
# dasovich-j 78414  Let's look some more.  I don't think there's a...
#            73641  Nice move into third place, Dad.\n\n\nCameron ...
#            61834  I am resending the same file as before (althou...
#            65347  Please RSVP if you haven't already done so by ...
#            60289                                               Here
#            57037  could you send my the slides that you put toge...
#            67670  If these guys are manipulating the market they...
#            78617  what's pepcid.  he has NO idea.  is he sure it...
#            81906  the voices of dissent have started....\n----- ...
#            64759  The responses from many of you indicate that m...
#
#                         user
# user
# beck-s     29795      beck-s
#            28933      beck-s
#            24495      beck-s
#            31891      beck-s
#            23954      beck-s
#            20799      beck-s
#            25823      beck-s
#            25812      beck-s
#            24463      beck-s
#            27931      beck-s
# dasovich-j 78414  dasovich-j
#            73641  dasovich-j
#            61834  dasovich-j
#            65347  dasovich-j
#            60289  dasovich-j
#            57037  dasovich-j
#            67670  dasovich-j
#            78617  dasovich-j
#            81906  dasovich-j
#            64759  dasovich-j

# %% [markdown]
# ### Have a look at word cloud for diffrent user

# %%
beck_s = df_1000[df_1000.user=="beck-s"]["content"].values
shackletons = df_1000[df_1000.user=="shackleton-s"]["content"].values

# %%
plt.figure(figsize=(16,13))
wc = WordCloud(background_color="black", max_words=10000, 
               stopwords=STOPWORDS, max_font_size= 40)
wc.generate(" ".join(beck_s))
plt.title("beck_s", fontsize=16)
plt.imshow(wc.recolor( colormap= 'Pastel1_r' , random_state=17), alpha=0.98)
plt.axis('off')
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %%
plt.figure(figsize=(16,13))
wc = WordCloud(background_color="black", max_words=10000, 
               stopwords=STOPWORDS, max_font_size= 40)
wc.generate(" ".join(beck_s))
plt.title("shackleton_s", fontsize=16)
plt.imshow(wc.recolor( colormap= 'Pastel1_r' , random_state=17), alpha=0.98)
plt.axis('off')
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %%
# Get doc structure for every sample. note:  this step will take around 1 hour.
df_1000["doc"] = df_1000.content.apply(nlp) # get doc structure for every sample, this step will take around 1 hour.
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-615-cac59245f4f2> in <module>()
# ----> 1 df_1000["doc"] = df_1000.content.apply(nlp)
#
# /Users/jingqin/venv3/lib/python3.6/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    2549             else:
#    2550                 values = self.asobject
# -> 2551                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    2552
#    2553         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/src/inference.pyx in pandas._libs.lib.map_infer()
#
# /Users/jingqin/venv3/lib/python3.6/site-packages/spacy/language.py in __call__(self, text, disable)
#     331             if name in disable:
#     332                 continue
# --> 333             doc = proc(doc)
#     334         return doc
#     335
#
# nn_parser.pyx in spacy.syntax.nn_parser.Parser.__call__()
#
# nn_parser.pyx in spacy.syntax.nn_parser.Parser.parse_batch()
#
# nn_parser.pyx in spacy.syntax.nn_parser.Parser.get_batch_model()
#
# nn_parser.pyx in spacy.syntax.nn_parser.precompute_hiddens.__init__()
#
# /Users/jingqin/venv3/lib/python3.6/site-packages/spacy/_ml.py in begin_update(self, X, drop)
#     146     def begin_update(self, X, drop=0.):
#     147         Yf = self.ops.xp.dot(X,
# --> 148             self.W.reshape((self.nF*self.nO*self.nP, self.nI)).T)
#     149         Yf = Yf.reshape((Yf.shape[0], self.nF, self.nO, self.nP))
#     150         Yf = self._add_padding(Yf)
#
# KeyboardInterrupt:

# %%
df_1000.describe()
# Out:
#                                           Message-ID  \
# count                                          12000
# unique                                         12000
# top     <3162701.1075842953057.JavaMail.evans@thyme>
# freq                                               1
#
#                                                   content       user  \
# count                                               12000      12000
# unique                                              11312         12
# top     The ClickAtHome team is pleased to announce th...  germany-c
# freq                                                    4       1000
#
#                                                       doc
# count                                               12000
# unique                                              12000
# top     (Not, a, bad, wire, story, -, relevant, for, o...
# freq                                                    1

# %% [markdown]
# ### Save dataframe to pickle file, because of size and doc structure, it can't be saved into csv, and also too big for into one single file

# %%
df_1000[:3000].to_pickle("emails_df_1000_12_tmp1.pkl")
df_1000[3000:6000].to_pickle("emails_df_1000_12_tmp2.pkl")
df_1000[6000:9000].to_pickle("emails_df_1000_12_tmp3.pkl")
df_1000[9000:].to_pickle("emails_df_1000_12_tmp4.pkl")

# %%
df1 = pd.read_pickle("emails_df_1000_12_tmp1.pkl")
df2 = pd.read_pickle("emails_df_1000_12_tmp2.pkl")
df3 = pd.read_pickle("emails_df_1000_12_tmp3.pkl")
df4 = pd.read_pickle("emails_df_1000_12_tmp4.pkl")
print(df1.head())
print(df2.head())
print(df3.head())
# Out:
#                                                  Message-ID  \
# user
# beck-s 31526   <8253436.1075855906483.JavaMail.evans@thyme>
#        31409   <8337492.1075855904083.JavaMail.evans@thyme>
#        24746   <8917002.1075855767799.JavaMail.evans@thyme>
#        25583   <9181139.1075855832794.JavaMail.evans@thyme>
#        25655  <17294707.1075855834331.JavaMail.evans@thyme>
#
#                                                         content    user  \
# user
# beck-s 31526  I will be out of the office after noon on Frid...  beck-s
#        31409  Can you join me at this meeting?  I plan to ta...  beck-s
#        24746  Sally - Plse see the attached summary that Ris...  beck-s
#        25583  Sally:\n\nBelow is the detail of what the "ext...  beck-s
#        25655  Ditto.  \n---------------------- Forwarded by ...  beck-s
#
#                                                             doc
# user
# beck-s 31526  (I, will, be, out, of, the, office, after, noo...
#        31409  (Can, you, join, me, at, this, meeting, ?,  , ...
#        24746  (Sally, -, Plse, see, the, attached, summary, ...
#        25583  (Sally, :, \n\n, Below, is, the, detail, of, w...
#        25655  (Ditto, .,  \n, ----------------------, Forwar...
#                                                      Message-ID  \
# user
# germany-c 132704  <18889855.1075840522637.JavaMail.evans@thyme>
#           131420  <11931857.1075861229017.JavaMail.evans@thyme>
#           127639  <12016281.1075853682160.JavaMail.evans@thyme>
#           125078  <31734435.1075853692963.JavaMail.evans@thyme>
#           132692  <20154475.1075840522375.JavaMail.evans@thyme>
#
#                                                             content  \
# user
# germany-c 132704  Lee Ann, sounds like Gloria is our key person....
#           131420  fyi...\n\n -----Original Message-----\nFrom: \...
#           127639  This is the Transco IT feeder for Zone 3 wellh...
#           125078  A new service type "Park & Loan - Non Pathed" ...
#           132692  Beth Jenkins gave me your name as an Enron con...
#
#                        user                                                doc
# user
# germany-c 132704  germany-c  (Lee, Ann, ,, sounds, like, Gloria, is, our, k...
#           131420  germany-c  (fyi, ..., \n\n , -----Original, Message-----,...
#           127639  germany-c  (This, is, the, Transco, IT, feeder, for, Zone...
#           125078  germany-c  (A, new, service, type, ", Park, &, Loan, -, N...
#           132692  germany-c  (Beth, Jenkins, gave, me, your, name, as, an, ...
#                                                   Message-ID  \
# user
# kean-s 245523  <30088961.1075848122773.JavaMail.evans@thyme>
#        239475  <21421832.1075846313080.JavaMail.evans@thyme>
#        232456  <18538435.1075846247819.JavaMail.evans@thyme>
#        251187   <8304165.1075858880564.JavaMail.evans@thyme>
#        228552  <16201086.1075846194356.JavaMail.evans@thyme>
#
#                                                          content    user  \
# user
# kean-s 245523  ----- Forwarded by Steven J Kean/NA/Enron on 0...  kean-s
#        239475  Please make sure that nothing goes out interna...  kean-s
#        232456  Please e:mail from Sarah Novosel below.\n\ngng...  kean-s
#        251187  We have already submitted our budget for PR, G...  kean-s
#        228552  Thanks, I also need to get some time with Shaw...  kean-s
#
#                                                              doc
# user
# kean-s 245523  (-----, Forwarded, by, Steven, J, Kean, /, NA,...
#        239475  (Please, make, sure, that, nothing, goes, out,...
#        232456  (Please, e, :, mail, from, Sarah, Novosel, bel...
#        251187  (We, have, already, submitted, our, budget, fo...
#        228552  (Thanks, ,, I, also, need, to, get, some, time...

# %%
frames = [df1, df2, df3, df4]

df_1000_12 = pd.concat(frames)

# %%
print(df_1000_12.head())
# Out:
#                                                  Message-ID  \
# user
# beck-s 31526   <8253436.1075855906483.JavaMail.evans@thyme>
#        31409   <8337492.1075855904083.JavaMail.evans@thyme>
#        24746   <8917002.1075855767799.JavaMail.evans@thyme>
#        25583   <9181139.1075855832794.JavaMail.evans@thyme>
#        25655  <17294707.1075855834331.JavaMail.evans@thyme>
#
#                                                         content    user  \
# user
# beck-s 31526  I will be out of the office after noon on Frid...  beck-s
#        31409  Can you join me at this meeting?  I plan to ta...  beck-s
#        24746  Sally - Plse see the attached summary that Ris...  beck-s
#        25583  Sally:\n\nBelow is the detail of what the "ext...  beck-s
#        25655  Ditto.  \n---------------------- Forwarded by ...  beck-s
#
#                                                             doc
# user
# beck-s 31526  (I, will, be, out, of, the, office, after, noo...
#        31409  (Can, you, join, me, at, this, meeting, ?,  , ...
#        24746  (Sally, -, Plse, see, the, attached, summary, ...
#        25583  (Sally, :, \n\n, Below, is, the, detail, of, w...
#        25655  (Ditto, .,  \n, ----------------------, Forwar...

# %%
df_1000_12 = df_1000_12.join(df_1000_12.doc.apply(features.sentence_based_features))

df_1000_12.head()
# Out:
#                                                  Message-ID  \
# user
# beck-s 31526   <8253436.1075855906483.JavaMail.evans@thyme>
#        31409   <8337492.1075855904083.JavaMail.evans@thyme>
#        24746   <8917002.1075855767799.JavaMail.evans@thyme>
#        25583   <9181139.1075855832794.JavaMail.evans@thyme>
#        25655  <17294707.1075855834331.JavaMail.evans@thyme>
#
#                                                         content    user  \
# user
# beck-s 31526  I will be out of the office after noon on Frid...  beck-s
#        31409  Can you join me at this meeting?  I plan to ta...  beck-s
#        24746  Sally - Plse see the attached summary that Ris...  beck-s
#        25583  Sally:\n\nBelow is the detail of what the "ext...  beck-s
#        25655  Ditto.  \n---------------------- Forwarded by ...  beck-s
#
#                                                             doc  \
# user
# beck-s 31526  (I, will, be, out, of, the, office, after, noo...
#        31409  (Can, you, join, me, at, this, meeting, ?,  , ...
#        24746  (Sally, -, Plse, see, the, attached, summary, ...
#        25583  (Sally, :, \n\n, Below, is, the, detail, of, w...
#        25655  (Ditto, .,  \n, ----------------------, Forwar...
#
#               avg_nr_word_per_sent  nr_sents  std_nr_word_per_sent
# user
# beck-s 31526             17.250000       4.0              9.878428
#        31409             21.526316      19.0             49.298826
#        24746             19.172414      29.0             12.050693
#        25583             10.114583      96.0              8.392816
#        25655             16.285714      14.0             15.329351

# %%
df_1000_12 = df_1000_12.join(df_1000_12.doc.apply(features.character_based_features))
df_1000_12.head()
# Out:
#                                                  Message-ID  \
# user
# beck-s 31526   <8253436.1075855906483.JavaMail.evans@thyme>
#        31409   <8337492.1075855904083.JavaMail.evans@thyme>
#        24746   <8917002.1075855767799.JavaMail.evans@thyme>
#        25583   <9181139.1075855832794.JavaMail.evans@thyme>
#        25655  <17294707.1075855834331.JavaMail.evans@thyme>
#
#                                                         content    user  \
# user
# beck-s 31526  I will be out of the office after noon on Frid...  beck-s
#        31409  Can you join me at this meeting?  I plan to ta...  beck-s
#        24746  Sally - Plse see the attached summary that Ris...  beck-s
#        25583  Sally:\n\nBelow is the detail of what the "ext...  beck-s
#        25655  Ditto.  \n---------------------- Forwarded by ...  beck-s
#
#                                                             doc  \
# user
# beck-s 31526  (I, will, be, out, of, the, office, after, noo...
#        31409  (Can, you, join, me, at, this, meeting, ?,  , ...
#        24746  (Sally, -, Plse, see, the, attached, summary, ...
#        25583  (Sally, :, \n\n, Below, is, the, detail, of, w...
#        25655  (Ditto, .,  \n, ----------------------, Forwar...
#
#               avg_nr_word_per_sent  nr_sents  std_nr_word_per_sent  nr_chars  \
# user
# beck-s 31526             17.250000       4.0              9.878428       224
#        31409             21.526316      19.0             49.298826      1514
#        24746             19.172414      29.0             12.050693      2147
#        25583             10.114583      96.0              8.392816      3816
#        25655             16.285714      14.0             15.329351      1008
#
#               nr_letters  nr_lower  nr_nums  nr_punctuation  nr_spaces  \
# user
# beck-s 31526         196       190       11               9          8
#        31409        1199       815       65             206         44
#        24746        1760      1585       56             146        185
#        25583        2675      2176      222             479        440
#        25655         747       657       33              95        133
#
#               nr_upper
# user
# beck-s 31526         6
#        31409       384
#        24746       175
#        25583       499
#        25655        90

# %%
df_1000_12 = df_1000_12.join(df_1000_12.doc.apply(features.punctuationr_based_features))
df_1000_12.head()
# Out:
#                                                  Message-ID  \
# user
# beck-s 31526   <8253436.1075855906483.JavaMail.evans@thyme>
#        31409   <8337492.1075855904083.JavaMail.evans@thyme>
#        24746   <8917002.1075855767799.JavaMail.evans@thyme>
#        25583   <9181139.1075855832794.JavaMail.evans@thyme>
#        25655  <17294707.1075855834331.JavaMail.evans@thyme>
#
#                                                         content    user  \
# user
# beck-s 31526  I will be out of the office after noon on Frid...  beck-s
#        31409  Can you join me at this meeting?  I plan to ta...  beck-s
#        24746  Sally - Plse see the attached summary that Ris...  beck-s
#        25583  Sally:\n\nBelow is the detail of what the "ext...  beck-s
#        25655  Ditto.  \n---------------------- Forwarded by ...  beck-s
#
#                                                             doc  \
# user
# beck-s 31526  (I, will, be, out, of, the, office, after, noo...
#        31409  (Can, you, join, me, at, this, meeting, ?,  , ...
#        24746  (Sally, -, Plse, see, the, attached, summary, ...
#        25583  (Sally, :, \n\n, Below, is, the, detail, of, w...
#        25655  (Ditto, .,  \n, ----------------------, Forwar...
#
#               avg_nr_word_per_sent  nr_sents  std_nr_word_per_sent  nr_chars  \
# user
# beck-s 31526             17.250000       4.0              9.878428       224
#        31409             21.526316      19.0             49.298826      1514
#        24746             19.172414      29.0             12.050693      2147
#        25583             10.114583      96.0              8.392816      3816
#        25655             16.285714      14.0             15.329351      1008
#
#               nr_letters  nr_lower      ...        nr_punctuation  nr_spaces  \
# user                                    ...
# beck-s 31526         196       190      ...                     9          8
#        31409        1199       815      ...                   206         44
#        24746        1760      1585      ...                   146        185
#        25583        2675      2176      ...                   479        440
#        25655         747       657      ...                    95        133
#
#               nr_upper  nr_colons  nr_commas  nr_dots  nr_exclamation  \
# user
# beck-s 31526         6          0          4        3               0
#        31409       384          5         31        6               1
#        24746       175          8         15       16               0
#        25583       499         49         16       22               0
#        25655        90         17          3        5               0
#
#               nr_hyphens  nr_question  nr_semicolons
# user
# beck-s 31526           2            0              0
#        31409           5            1              0
#        24746           4            8              0
#        25583           1            7              0
#        25655           1            0              0
#
# [5 rows x 21 columns]

# %%
df_1000_12 = df_1000_12.join(df_1000_12.doc.apply(features.word_based_features))
df_1000_12.head()
# Out:
#                                                  Message-ID  \
# user
# beck-s 31526   <8253436.1075855906483.JavaMail.evans@thyme>
#        31409   <8337492.1075855904083.JavaMail.evans@thyme>
#        24746   <8917002.1075855767799.JavaMail.evans@thyme>
#        25583   <9181139.1075855832794.JavaMail.evans@thyme>
#        25655  <17294707.1075855834331.JavaMail.evans@thyme>
#
#                                                         content    user  \
# user
# beck-s 31526  I will be out of the office after noon on Frid...  beck-s
#        31409  Can you join me at this meeting?  I plan to ta...  beck-s
#        24746  Sally - Plse see the attached summary that Ris...  beck-s
#        25583  Sally:\n\nBelow is the detail of what the "ext...  beck-s
#        25655  Ditto.  \n---------------------- Forwarded by ...  beck-s
#
#                                                             doc  \
# user
# beck-s 31526  (I, will, be, out, of, the, office, after, noo...
#        31409  (Can, you, join, me, at, this, meeting, ?,  , ...
#        24746  (Sally, -, Plse, see, the, attached, summary, ...
#        25583  (Sally, :, \n\n, Below, is, the, detail, of, w...
#        25655  (Ditto, .,  \n, ----------------------, Forwar...
#
#               avg_nr_word_per_sent  nr_sents  std_nr_word_per_sent  nr_chars  \
# user
# beck-s 31526             17.250000       4.0              9.878428       224
#        31409             21.526316      19.0             49.298826      1514
#        24746             19.172414      29.0             12.050693      2147
#        25583             10.114583      96.0              8.392816      3816
#        25655             16.285714      14.0             15.329351      1008
#
#               nr_letters  nr_lower    ...     nr_question  nr_semicolons  \
# user                                  ...
# beck-s 31526         196       190    ...               0              0
#        31409        1199       815    ...               1              0
#        24746        1760      1585    ...               8              0
#        25583        2675      2176    ...               7              0
#        25655         747       657    ...               0              0
#
#                    HTR       TTR  avg_characters_per_word  most_frequency  \
# user
# beck-s 31526  0.520000  0.720000                 3.920000             4.0
#        31409  0.537736  0.674528                 4.466981            22.0
#        24746  0.376263  0.540404                 4.320707            13.0
#        25583  0.216667  0.361667                 4.191667            22.0
#        25655  0.591241  0.744526                 5.416058             8.0
#
#               nr_error  nr_longwords  nr_stopwords  nr_words
# user
# beck-s 31526       0.0          12.0          27.0      50.0
#        31409       0.0          62.0          51.0     212.0
#        24746       0.0         113.0         167.0     396.0
#        25583       0.0         129.0         198.0     600.0
#        25655       0.0          64.0          39.0     137.0
#
# [5 rows x 29 columns]

# %%
df_1000_12 = df_1000_12.join(df_1000_12.doc.apply(features.syntactic_features))
df_1000_12.head()
# Out:
#                                                  Message-ID  \
# user
# beck-s 31526   <8253436.1075855906483.JavaMail.evans@thyme>
#        31409   <8337492.1075855904083.JavaMail.evans@thyme>
#        24746   <8917002.1075855767799.JavaMail.evans@thyme>
#        25583   <9181139.1075855832794.JavaMail.evans@thyme>
#        25655  <17294707.1075855834331.JavaMail.evans@thyme>
#
#                                                         content    user  \
# user
# beck-s 31526  I will be out of the office after noon on Frid...  beck-s
#        31409  Can you join me at this meeting?  I plan to ta...  beck-s
#        24746  Sally - Plse see the attached summary that Ris...  beck-s
#        25583  Sally:\n\nBelow is the detail of what the "ext...  beck-s
#        25655  Ditto.  \n---------------------- Forwarded by ...  beck-s
#
#                                                             doc  \
# user
# beck-s 31526  (I, will, be, out, of, the, office, after, noo...
#        31409  (Can, you, join, me, at, this, meeting, ?,  , ...
#        24746  (Sally, -, Plse, see, the, attached, summary, ...
#        25583  (Sally, :, \n\n, Below, is, the, detail, of, w...
#        25655  (Ditto, .,  \n, ----------------------, Forwar...
#
#               avg_nr_word_per_sent  nr_sents  std_nr_word_per_sent  nr_chars  \
# user
# beck-s 31526             17.250000       4.0              9.878428       224
#        31409             21.526316      19.0             49.298826      1514
#        24746             19.172414      29.0             12.050693      2147
#        25583             10.114583      96.0              8.392816      3816
#        25655             16.285714      14.0             15.329351      1008
#
#               nr_letters  nr_lower   ...         TTR  avg_characters_per_word  \
# user                                 ...
# beck-s 31526         196       190   ...    0.720000                 3.920000
#        31409        1199       815   ...    0.674528                 4.466981
#        24746        1760      1585   ...    0.540404                 4.320707
#        25583        2675      2176   ...    0.361667                 4.191667
#        25655         747       657   ...    0.744526                 5.416058
#
#               most_frequency  nr_error  nr_longwords  nr_stopwords  nr_words  \
# user
# beck-s 31526             4.0       0.0          12.0          27.0      50.0
#        31409            22.0       0.0          62.0          51.0     212.0
#        24746            13.0       0.0         113.0         167.0     396.0
#        25583            22.0       0.0         129.0         198.0     600.0
#        25655             8.0       0.0          64.0          39.0     137.0
#
#               avg_length_np  nr_function  nr_pos
# user
# beck-s 31526       7.857143         21.0    14.0
#        31409      11.446809         44.0    16.0
#        24746      10.201835        132.0    17.0
#        25583       9.891192        174.0    16.0
#        25655      15.307692         36.0    15.0
#
# [5 rows x 32 columns]

# %%
df_1000_12 = df_1000_12.join(df_1000_12.doc.apply(features.semantic_features))
df_1000_12.head()
# Out:
#                                                  Message-ID  \
# user
# beck-s 31526   <8253436.1075855906483.JavaMail.evans@thyme>
#        31409   <8337492.1075855904083.JavaMail.evans@thyme>
#        24746   <8917002.1075855767799.JavaMail.evans@thyme>
#        25583   <9181139.1075855832794.JavaMail.evans@thyme>
#        25655  <17294707.1075855834331.JavaMail.evans@thyme>
#
#                                                         content    user  \
# user
# beck-s 31526  I will be out of the office after noon on Frid...  beck-s
#        31409  Can you join me at this meeting?  I plan to ta...  beck-s
#        24746  Sally - Plse see the attached summary that Ris...  beck-s
#        25583  Sally:\n\nBelow is the detail of what the "ext...  beck-s
#        25655  Ditto.  \n---------------------- Forwarded by ...  beck-s
#
#                                                             doc  \
# user
# beck-s 31526  (I, will, be, out, of, the, office, after, noo...
#        31409  (Can, you, join, me, at, this, meeting, ?,  , ...
#        24746  (Sally, -, Plse, see, the, attached, summary, ...
#        25583  (Sally, :, \n\n, Below, is, the, detail, of, w...
#        25655  (Ditto, .,  \n, ----------------------, Forwar...
#
#               avg_nr_word_per_sent  nr_sents  std_nr_word_per_sent  nr_chars  \
# user
# beck-s 31526             17.250000       4.0              9.878428       224
#        31409             21.526316      19.0             49.298826      1514
#        24746             19.172414      29.0             12.050693      2147
#        25583             10.114583      96.0              8.392816      3816
#        25655             16.285714      14.0             15.329351      1008
#
#               nr_letters  nr_lower        ...         nr_error  nr_longwords  \
# user                                      ...
# beck-s 31526         196       190        ...              0.0          12.0
#        31409        1199       815        ...              0.0          62.0
#        24746        1760      1585        ...              0.0         113.0
#        25583        2675      2176        ...              0.0         129.0
#        25655         747       657        ...              0.0          64.0
#
#               nr_stopwords  nr_words  avg_length_np  nr_function  nr_pos  \
# user
# beck-s 31526          27.0      50.0       7.857143         21.0    14.0
#        31409          51.0     212.0      11.446809         44.0    16.0
#        24746         167.0     396.0      10.201835        132.0    17.0
#        25583         198.0     600.0       9.891192        174.0    16.0
#        25655          39.0     137.0      15.307692         36.0    15.0
#
#               nr_named_entity  nr_neg_word  nr_positive_word
# user
# beck-s 31526               15            0                 0
#        31409              193            0                 1
#        24746              151            0                 2
#        25583              342            0                 0
#        25655               80            0                 0
#
# [5 rows x 35 columns]

# %%
df_1000_12 = df_1000_12.join(df_1000_12.content.apply(features.semantic_features_content))
df_1000_12.head()
# Out:
#                                                  Message-ID  \
# user
# beck-s 31526   <8253436.1075855906483.JavaMail.evans@thyme>
#        31409   <8337492.1075855904083.JavaMail.evans@thyme>
#        24746   <8917002.1075855767799.JavaMail.evans@thyme>
#        25583   <9181139.1075855832794.JavaMail.evans@thyme>
#        25655  <17294707.1075855834331.JavaMail.evans@thyme>
#
#                                                         content    user  \
# user
# beck-s 31526  I will be out of the office after noon on Frid...  beck-s
#        31409  Can you join me at this meeting?  I plan to ta...  beck-s
#        24746  Sally - Plse see the attached summary that Ris...  beck-s
#        25583  Sally:\n\nBelow is the detail of what the "ext...  beck-s
#        25655  Ditto.  \n---------------------- Forwarded by ...  beck-s
#
#                                                             doc  \
# user
# beck-s 31526  (I, will, be, out, of, the, office, after, noo...
#        31409  (Can, you, join, me, at, this, meeting, ?,  , ...
#        24746  (Sally, -, Plse, see, the, attached, summary, ...
#        25583  (Sally, :, \n\n, Below, is, the, detail, of, w...
#        25655  (Ditto, .,  \n, ----------------------, Forwar...
#
#               avg_nr_word_per_sent  nr_sents  std_nr_word_per_sent  nr_chars  \
# user
# beck-s 31526             17.250000       4.0              9.878428       224
#        31409             21.526316      19.0             49.298826      1514
#        24746             19.172414      29.0             12.050693      2147
#        25583             10.114583      96.0              8.392816      3816
#        25655             16.285714      14.0             15.329351      1008
#
#               nr_letters  nr_lower       ...        nr_stopwords  nr_words  \
# user                                     ...
# beck-s 31526         196       190       ...                27.0      50.0
#        31409        1199       815       ...                51.0     212.0
#        24746        1760      1585       ...               167.0     396.0
#        25583        2675      2176       ...               198.0     600.0
#        25655         747       657       ...                39.0     137.0
#
#               avg_length_np  nr_function  nr_pos  nr_named_entity  \
# user
# beck-s 31526       7.857143         21.0    14.0               15
#        31409      11.446809         44.0    16.0              193
#        24746      10.201835        132.0    17.0              151
#        25583       9.891192        174.0    16.0              342
#        25655      15.307692         36.0    15.0               80
#
#               nr_neg_word  nr_positive_word  nr_emoticons  score_semantic
# user
# beck-s 31526            0                 0           3.0          0.0258
#        31409            0                 1           1.0          0.9020
#        24746            0                 2           4.0          0.9634
#        25583            0                 0          10.0          0.9764
#        25655            0                 0           3.0          0.9360
#
# [5 rows x 37 columns]

# %%
# emot doesn't work as expected, this feature will be removed
s = str(df_1000_12['content'][4])
print (emot.emoticons(s))
print (s)
# Out:
# [{'value': ')', 'location': [506, 507]}, {'value': ')', 'location': [540, 541]}, {'value': ':3', 'location': [1039, 1041]}]
# Ditto.
# ---------------------- Forwarded by Sally Beck/HOU/ECT on 05/30/2000 04:29 PM
# ---------------------------
#
# From:  Information Risk Management/HOU/ECT
#
# Subject: Your approval is requested
#
# 	Security Resource Request System
# Application Approval
# Please review and act upon this request. You have received this eMail because
# you are listed as an approver on the original request.
# 			Instructions
# For: 	Adriane Moratto
# Request	Original:
# Application Name:	EOL - Other (US)
# Request Type:	Grant
# Role(s):
# Comments:	Commercial set up for Marketing group		Review the request in the Request
# section at left.
# 			For more information regarding who the request is for, do the following:
# 			Click on the name for PeopleFinder info
# 			See the Further Information section below
# 			In the Approval Section, select Approve or Reject, enter comments as
# necessary and click [Submit].
#
#
#
#
# 	Further Information
#
# Requestor:			Adriane Moratto
# Manager:	Lorraine Becker
# Request Date:	05/26/2000 12:32:12 PM
# RC #:	2172	WO #:
# Company #:	413	Priority:	High
# General Comments:

# %%
df_1000_12[11980:]
# Out:
#                                                     Message-ID  \
# user
# taylor-m 482807  <30639685.1075859999215.JavaMail.evans@thyme>
#          481785  <29436537.1075860245890.JavaMail.evans@thyme>
#          472462  <23013397.1075859901929.JavaMail.evans@thyme>
#          481036   <9970686.1075860027365.JavaMail.evans@thyme>
#          473434   <4449316.1075859882240.JavaMail.evans@thyme>
#          483286  <20719202.1075860039501.JavaMail.evans@thyme>
#          477710   <6579442.1075860216610.JavaMail.evans@thyme>
#          481528  <12374497.1075860239435.JavaMail.evans@thyme>
#          485304  <30595536.1075860057582.JavaMail.evans@thyme>
#          484846   <6910129.1075860054749.JavaMail.evans@thyme>
#          482674  <19428717.1075859996184.JavaMail.evans@thyme>
#          482637   <4188027.1075859995410.JavaMail.evans@thyme>
#          479670  <21437862.1075858611492.JavaMail.evans@thyme>
#          481887  <16988267.1075860248936.JavaMail.evans@thyme>
#          480753  <27794740.1075860019922.JavaMail.evans@thyme>
#          480805  <20842868.1075860021220.JavaMail.evans@thyme>
#          480220   <3524842.1075862100661.JavaMail.evans@thyme>
#          478327   <8917432.1075860227565.JavaMail.evans@thyme>
#          482103  <30862833.1075860254062.JavaMail.evans@thyme>
#          484601  <18183173.1075860082097.JavaMail.evans@thyme>
#
#                                                            content      user  \
# user
# taylor-m 482807   Dear Andrea:\n\n As discussed, these are prel...  taylor-m
#          481785  Bob -\n\nMy initial response is that the amend...  taylor-m
#          472462  Have you seen this?\n---------------------- Fo...  taylor-m
#          481036  FYI.\n----- Forwarded by Dan J Hyvl/HOU/ECT on...  taylor-m
#          473434  As you are already aware,  the West desk is ma...  taylor-m
#          483286  > -----Original Message-----\n> From: Garrett,...  taylor-m
#          477710  You obviously know far more than me....but I w...  taylor-m
#          481528  We have received an executed financial master ...  taylor-m
#          485304  Louise,\n\nI hope you had a pleasant weekend i...  taylor-m
#          484846  Looks good to me.\n\n\n\n\nCarol St Clair\n05/...  taylor-m
#          482674  ---------------------- Forwarded by Dave Samue...  taylor-m
#          482637  Per Rod's comments, are we comfortable with th...  taylor-m
#          479670  I will try too, but I can't seem to get throug...  taylor-m
#          481887  Good morning,\n\nJust a heads up to let you kn...  taylor-m
#          480753  How did we get comfortable with MG charging co...  taylor-m
#          480805  Here are the revised term sheet, confirmation ...  taylor-m
#          480220  Please copy the attached exe to C:\Program Fil...  taylor-m
#          478327  OK, then we set it at 3:30 Houston time (5:30 ...  taylor-m
#          482103  ?\n----- Original Message -----  \nFrom: green...  taylor-m
#          484601  My answers below in red.\n\n\n\n\tBob Bowen\n\...  taylor-m
#
#                                                                doc  \
# user
# taylor-m 482807  ( , Dear, Andrea, :, \n\n , As, discussed, ,, ...
#          481785  (Bob, -, \n\n, My, initial, response, is, that...
#          472462  (Have, you, seen, this, ?, \n, ---------------...
#          481036  (FYI, ., \n, -----, Forwarded, by, Dan, J, Hyv...
#          473434  (As, you, are, already, aware, ,,  , the, West...
#          483286  (>, -----Original, Message-----, \n, >, From, ...
#          477710  (You, obviously, know, far, more, than, me, .....
#          481528  (We, have, received, an, executed, financial, ...
#          485304  (Louise, ,, \n\n, I, hope, you, had, a, pleasa...
#          484846  (Looks, good, to, me, ., \n\n\n\n\n, Carol, St...
#          482674  (----------------------, Forwarded, by, Dave, ...
#          482637  (Per, Rod, 's, comments, ,, are, we, comfortab...
#          479670  (I, will, try, too, ,, but, I, ca, n't, seem, ...
#          481887  (Good, morning, ,, \n\n, Just, a, heads, up, t...
#          480753  (How, did, we, get, comfortable, with, MG, cha...
#          480805  (Here, are, the, revised, term, sheet, ,, conf...
#          480220  (Please, copy, the, attached, exe, to, C:\Prog...
#          478327  (OK, ,, then, we, set, it, at, 3:30, Houston, ...
#          482103  (?, \n, -----, Original, Message, -----,  \n, ...
#          484601  (My, answers, below, in, red, ., \n\n\n\n\t, B...
#
#                  avg_nr_word_per_sent  nr_sents  std_nr_word_per_sent  \
# user
# taylor-m 482807             11.742857      35.0             13.211721
#          481785             20.400000      25.0             17.909495
#          472462             16.545455      11.0             11.527043
#          481036              7.846154      13.0              6.693855
#          473434             44.444444       9.0             39.265478
#          483286             11.150943      53.0             15.794834
#          477710             13.670213      94.0             12.173820
#          481528             14.428571       7.0             11.645559
#          485304             19.750000       4.0             15.564382
#          484846             12.285714       7.0             12.392394
#          482674             17.513514      37.0             13.005601
#          482637             10.307692      13.0              8.380380
#          479670             16.885714      35.0             21.980970
#          481887             26.285714       7.0             14.795430
#          480753             13.500000       2.0              0.707107
#          480805             12.447368      76.0             12.017093
#          480220              6.000000       4.0              5.354126
#          478327             14.950000      20.0             15.094352
#          482103             10.000000      12.0              7.236272
#          484601             16.166667      60.0             10.891089
#
#                  nr_chars  nr_letters  nr_lower       ...        nr_stopwords  \
# user                                                  ...
# taylor-m 482807      1368        1097      1033       ...                83.0
#          481785      2023        1825      1756       ...               206.0
#          472462       708         540       486       ...                51.0
#          481036       364         269       192       ...                12.0
#          473434      1554        1474      1423       ...               168.0
#          483286      2043        1626      1404       ...                72.0
#          477710      5275        4525      4253       ...               323.0
#          481528       461         403       356       ...                12.0
#          485304       298         278       265       ...                30.0
#          484846       299         245       193       ...                16.0
#          482674      2587        2345      2270       ...               262.0
#          482637       594         394       332       ...                16.0
#          479670      1772        1500      1439       ...               204.0
#          481887       722         661       620       ...                57.0
#          480753       125         121       117       ...                13.0
#          480805      3362        2667      2363       ...               173.0
#          480220       116         102        92       ...                 7.0
#          478327      1169         995       879       ...                73.0
#          482103       493         402       339       ...                20.0
#          484601      3747        3308      2973       ...               315.0
#
#                  nr_words  avg_length_np  nr_function  nr_pos  \
# user
# taylor-m 482807     200.0      11.096774         74.0    17.0
#          481785     378.0      10.457143        152.0    16.0
#          472462     118.0      10.676471         42.0    15.0
#          481036      61.0      12.947368         12.0    13.0
#          473434     326.0      11.038462        128.0    14.0
#          483286     229.0      12.422680         60.0    17.0
#          477710     853.0      12.023346        281.0    16.0
#          481528      63.0      16.250000         10.0    11.0
#          485304      62.0      11.200000         29.0    13.0
#          484846      51.0      11.294118         12.0    14.0
#          482674     499.0      10.042254        178.0    16.0
#          482637      69.0      10.590909         16.0    14.0
#          479670     352.0       7.571429        155.0    16.0
#          481887     137.0      14.468750         37.0    17.0
#          480753      24.0       9.000000          7.0    10.0
#          480805     472.0      11.282051        155.0    17.0
#          480220      18.0      11.166667          8.0    12.0
#          478327     197.0      11.790323         62.0    16.0
#          482103      61.0      12.700000         16.0    16.0
#          484601     699.0      11.291262        226.0    17.0
#
#                  nr_named_entity  nr_neg_word  nr_positive_word  nr_emoticons  \
# user
# taylor-m 482807               98            0                 0           3.0
#          481785               71            1                 1           7.0
#          472462               39            0                 0           2.0
#          481036               32            0                 0           0.0
#          473434               63            0                 3           5.0
#          483286              105            0                 1           6.0
#          477710              360            8                 1          22.0
#          481528               41            0                 0           2.0
#          485304               13            0                 1           1.0
#          484846               32            0                 0           2.0
#          482674              104            2                 0           6.0
#          482637               40            0                 1           0.0
#          479670               46            1                 0           8.0
#          481887               27            0                 0           6.0
#          480753                1            0                 1           0.0
#          480805              232            0                 0           3.0
#          480220                3            0                 0           2.0
#          478327               96            0                 0           6.0
#          482103               39            0                 0           1.0
#          484601              163            0                 0          13.0
#
#                  score_semantic
# user
# taylor-m 482807          0.9799
#          481785          0.9192
#          472462          0.5994
#          481036          0.8668
#          473434          0.8946
#          483286          0.9616
#          477710         -0.9904
#          481528          0.9382
#          485304          0.8271
#          484846          0.8106
#          482674          0.9390
#          482637          0.9842
#          479670          0.9829
#          481887          0.9231
#          480753          0.6440
#          480805          0.9888
#          480220          0.3612
#          478327          0.9343
#          482103          0.8299
#          484601          0.9947
#
# [20 rows x 37 columns]

# %% [markdown]
# ### Digitize classes

# %%
df_1000_12.user.unique()
# Out:
# array(['beck-s', 'dasovich-j', 'farmer-d', 'germany-c', 'jones-t',
#        'kaminski-v', 'kean-s', 'mann-k', 'nemec-g', 'shackleton-s',
#        'symes-k', 'taylor-m'], dtype=object)

# %%
df_1000_12['user'] = df_1000_12['user'].map( {'beck-s': 1, 'dasovich-j': 2, 'farmer-d': 3, 'germany-c': 4,
                                              'jones-t': 5, 'kaminski-v': 6, 'kean-s': 7, 'mann-k': 8,
                                             'nemec-g': 9, 'shackleton-s': 10, 'symes-k': 11, 'taylor-m': 12} ).astype(int)

df_1000_12.head()
# Out:
#                                                  Message-ID  \
# user
# beck-s 31526   <8253436.1075855906483.JavaMail.evans@thyme>
#        31409   <8337492.1075855904083.JavaMail.evans@thyme>
#        24746   <8917002.1075855767799.JavaMail.evans@thyme>
#        25583   <9181139.1075855832794.JavaMail.evans@thyme>
#        25655  <17294707.1075855834331.JavaMail.evans@thyme>
#
#                                                         content  user  \
# user
# beck-s 31526  I will be out of the office after noon on Frid...     1
#        31409  Can you join me at this meeting?  I plan to ta...     1
#        24746  Sally - Plse see the attached summary that Ris...     1
#        25583  Sally:\n\nBelow is the detail of what the "ext...     1
#        25655  Ditto.  \n---------------------- Forwarded by ...     1
#
#                                                             doc  \
# user
# beck-s 31526  (I, will, be, out, of, the, office, after, noo...
#        31409  (Can, you, join, me, at, this, meeting, ?,  , ...
#        24746  (Sally, -, Plse, see, the, attached, summary, ...
#        25583  (Sally, :, \n\n, Below, is, the, detail, of, w...
#        25655  (Ditto, .,  \n, ----------------------, Forwar...
#
#               avg_nr_word_per_sent  nr_sents  std_nr_word_per_sent  nr_chars  \
# user
# beck-s 31526             17.250000       4.0              9.878428       224
#        31409             21.526316      19.0             49.298826      1514
#        24746             19.172414      29.0             12.050693      2147
#        25583             10.114583      96.0              8.392816      3816
#        25655             16.285714      14.0             15.329351      1008
#
#               nr_letters  nr_lower       ...        nr_stopwords  nr_words  \
# user                                     ...
# beck-s 31526         196       190       ...                27.0      50.0
#        31409        1199       815       ...                51.0     212.0
#        24746        1760      1585       ...               167.0     396.0
#        25583        2675      2176       ...               198.0     600.0
#        25655         747       657       ...                39.0     137.0
#
#               avg_length_np  nr_function  nr_pos  nr_named_entity  \
# user
# beck-s 31526       7.857143         21.0    14.0               15
#        31409      11.446809         44.0    16.0              193
#        24746      10.201835        132.0    17.0              151
#        25583       9.891192        174.0    16.0              342
#        25655      15.307692         36.0    15.0               80
#
#               nr_neg_word  nr_positive_word  nr_emoticons  score_semantic
# user
# beck-s 31526            0                 0           3.0          0.0258
#        31409            0                 1           1.0          0.9020
#        24746            0                 2           4.0          0.9634
#        25583            0                 0          10.0          0.9764
#        25655            0                 0           3.0          0.9360
#
# [5 rows x 37 columns]

# %%
df_1000_12.index = list(range(len(df_1000_12.index)))

# %%
df_1000_12.head()
# Out:
#                                       Message-ID  \
# 0   <8253436.1075855906483.JavaMail.evans@thyme>
# 1   <8337492.1075855904083.JavaMail.evans@thyme>
# 2   <8917002.1075855767799.JavaMail.evans@thyme>
# 3   <9181139.1075855832794.JavaMail.evans@thyme>
# 4  <17294707.1075855834331.JavaMail.evans@thyme>
#
#                                              content  user  \
# 0  I will be out of the office after noon on Frid...     1
# 1  Can you join me at this meeting?  I plan to ta...     1
# 2  Sally - Plse see the attached summary that Ris...     1
# 3  Sally:\n\nBelow is the detail of what the "ext...     1
# 4  Ditto.  \n---------------------- Forwarded by ...     1
#
#                                                  doc  avg_nr_word_per_sent  \
# 0  (I, will, be, out, of, the, office, after, noo...             17.250000
# 1  (Can, you, join, me, at, this, meeting, ?,  , ...             21.526316
# 2  (Sally, -, Plse, see, the, attached, summary, ...             19.172414
# 3  (Sally, :, \n\n, Below, is, the, detail, of, w...             10.114583
# 4  (Ditto, .,  \n, ----------------------, Forwar...             16.285714
#
#    nr_sents  std_nr_word_per_sent  nr_chars  nr_letters  nr_lower  \
# 0       4.0              9.878428       224         196       190
# 1      19.0             49.298826      1514        1199       815
# 2      29.0             12.050693      2147        1760      1585
# 3      96.0              8.392816      3816        2675      2176
# 4      14.0             15.329351      1008         747       657
#
#         ...        nr_stopwords  nr_words  avg_length_np  nr_function  nr_pos  \
# 0       ...                27.0      50.0       7.857143         21.0    14.0
# 1       ...                51.0     212.0      11.446809         44.0    16.0
# 2       ...               167.0     396.0      10.201835        132.0    17.0
# 3       ...               198.0     600.0       9.891192        174.0    16.0
# 4       ...                39.0     137.0      15.307692         36.0    15.0
#
#    nr_named_entity  nr_neg_word  nr_positive_word  nr_emoticons  \
# 0               15            0                 0           3.0
# 1              193            0                 1           1.0
# 2              151            0                 2           4.0
# 3              342            0                 0          10.0
# 4               80            0                 0           3.0
#
#    score_semantic
# 0          0.0258
# 1          0.9020
# 2          0.9634
# 3          0.9764
# 4          0.9360
#
# [5 rows x 37 columns]

# %%
df_1000_12.drop(['doc', 'content', 'Message-ID','nr_emoticons',"nr_error"], axis=1, inplace=True)
df_1000_12.head()
# Out:
#    user  avg_nr_word_per_sent  nr_sents  std_nr_word_per_sent  nr_chars  \
# 0     1             17.250000       4.0              9.878428       224
# 1     1             21.526316      19.0             49.298826      1514
# 2     1             19.172414      29.0             12.050693      2147
# 3     1             10.114583      96.0              8.392816      3816
# 4     1             16.285714      14.0             15.329351      1008
#
#    nr_letters  nr_lower  nr_nums  nr_punctuation  nr_spaces       ...        \
# 0         196       190       11               9          8       ...
# 1        1199       815       65             206         44       ...
# 2        1760      1585       56             146        185       ...
# 3        2675      2176      222             479        440       ...
# 4         747       657       33              95        133       ...
#
#    nr_longwords  nr_stopwords  nr_words  avg_length_np  nr_function  nr_pos  \
# 0          12.0          27.0      50.0       7.857143         21.0    14.0
# 1          62.0          51.0     212.0      11.446809         44.0    16.0
# 2         113.0         167.0     396.0      10.201835        132.0    17.0
# 3         129.0         198.0     600.0       9.891192        174.0    16.0
# 4          64.0          39.0     137.0      15.307692         36.0    15.0
#
#    nr_named_entity  nr_neg_word  nr_positive_word  score_semantic
# 0               15            0                 0          0.0258
# 1              193            0                 1          0.9020
# 2              151            0                 2          0.9634
# 3              342            0                 0          0.9764
# 4               80            0                 0          0.9360
#
# [5 rows x 32 columns]

# %%
df_1000_12.shape
# Out:
# (12000, 32)

# %% [markdown]
# ### Statistics for single training example

# %%
df_1000_12.to_csv("Statistics_for_single_training_example.csv")

# %% [markdown]
# ### Aggregate per author:

# %%
df_t = df_1000_12.groupby('user').sum()

# %%
df_t.to_csv("Aggregate_per_author.csv")

# %%
df_1000_12 = pd.read_csv("../data/Statistics_for_single_training_example.csv",index_col=0)

# %%
print(df_1000_12.shape)
print(df_1000_12.head)
# Out:
# (12000, 32)
# <bound method NDFrame.head of        user  avg_nr_word_per_sent  nr_sents  std_nr_word_per_sent  nr_chars  \
# 0         1             17.250000       4.0              9.878428       224
# 1         1             21.526316      19.0             49.298826      1514
# 2         1             19.172414      29.0             12.050693      2147
# 3         1             10.114583      96.0              8.392816      3816
# 4         1             16.285714      14.0             15.329351      1008
# 5         1              7.500000       4.0              4.203173       124
# 6         1             19.103448      29.0             14.548797      2229
# 7         1             23.923077      26.0             17.558868      2397
# 8         1             14.750000       4.0              9.604686       209
# 9         1             13.833333      24.0             15.403745      1232
# 10        1             17.833333       6.0              5.076088       425
# 11        1             14.035714      28.0             12.591832      1559
# 12        1             10.000000       3.0              6.557439       120
# 13        1             16.204545      44.0             18.665451      2607
# 14        1             10.777778      27.0              7.996794      1035
# 15        1             52.000000       1.0              0.000000       191
# 16        1              7.440000      25.0              8.312039       839
# 17        1              9.758621      29.0              7.781182      1064
# 18        1             15.852941      34.0             15.651764      2149
# 19        1              9.083333      24.0             10.429543       959
# 20        1             15.611111      18.0              9.369154      1123
# 21        1             12.500000      12.0             11.587611       633
# 22        1             20.000000       4.0              7.615773       349
# 23        1             14.558824      34.0             13.008601      2016
# 24        1             24.764706      17.0             28.734843      1676
# 25        1              8.653846      26.0              7.331806       803
# 26        1             10.250000       8.0              7.166390       300
# 27        1             16.000000       2.0             12.727922       103
# 28        1             19.000000       6.0             12.790622       476
# 29        1             18.761905      21.0             19.712698      1434
# ...     ...                   ...       ...                   ...       ...
# 11970    12             11.452830      53.0             16.373720      2207
# 11971    12             18.563636      55.0             16.681953      3799
# 11972    12              9.217391      23.0             10.099309       899
# 11973    12             12.952607     211.0             10.821831     15890
# 11974    12             15.230769      13.0              8.053507       732
# 11975    12             19.272727      11.0              7.656251       903
# 11976    12             14.000000       2.0              9.899495       106
# 11977    12             13.450000      60.0             13.438403      3053
# 11978    12             32.900000      10.0             22.536144      1449
# 11979    12             16.000000       3.0             11.532563       210
# 11980    12             11.742857      35.0             13.211721      1368
# 11981    12             20.400000      25.0             17.909495      2023
# 11982    12             16.545455      11.0             11.527043       708
# 11983    12              7.846154      13.0              6.693855       364
# 11984    12             44.444444       9.0             39.265478      1554
# 11985    12             11.150943      53.0             15.794834      2043
# 11986    12             13.670213      94.0             12.173820      5275
# 11987    12             14.428571       7.0             11.645559       461
# 11988    12             19.750000       4.0             15.564382       298
# 11989    12             12.285714       7.0             12.392394       299
# 11990    12             17.513514      37.0             13.005601      2587
# 11991    12             10.307692      13.0              8.380380       594
# 11992    12             16.885714      35.0             21.980970      1772
# 11993    12             26.285714       7.0             14.795430       722
# 11994    12             13.500000       2.0              0.707107       125
# 11995    12             12.447368      76.0             12.017093      3362
# 11996    12              6.000000       4.0              5.354126       116
# 11997    12             14.950000      20.0             15.094352      1169
# 11998    12             10.000000      12.0              7.236272       493
# 11999    12             16.166667      60.0             10.891089      3747
#
#        nr_letters  nr_lower  nr_nums  nr_punctuation  nr_spaces  \
# 0             196       190       11               9          8
# 1            1199       815       65             206         44
# 2            1760      1585       56             146        185
# 3            2675      2176      222             479        440
# 4             747       657       33              95        133
# 5             108       103        0               4         12
# 6            1847      1705       62             175        145
# 7            2225      2076       27              97         48
# 8             196       183        0               3         10
# 9             931       648       44             158         99
# 10            403       397        0               9         13
# 11           1272      1071       99              81        107
# 12            112       108        0               2          6
# 13           2146      1882       81             211        169
# 14            837       727       32              92         74
# 15            170       155       12               4          5
# 16            606       529       52              93         88
# 17            850       799       42             103         69
# 18           1882      1659       26              91        150
# 19            617       488       77             166         99
# 20            943       803       26             116         38
# 21            561       528        9              34         29
# 22            324       301        9               6         10
# 23           1675      1554       75             117        149
# 24           1447      1182       24             156         49
# 25            571       500       24              73        135
# 26            224       191       22              33         21
# 27             94        89        0               4          5
# 28            452       435        0              11         13
# 29           1272      1183       17             101         44
# ...           ...       ...      ...             ...        ...
# 11970        1525      1326      126             389        167
# 11971        3325      2997       77             237        160
# 11972         595       470       89             148         67
# 11973       11802     10967     1633            2038        417
# 11974         630       580       34              43         25
# 11975         799       759       29              46         29
# 11976          90        75        5               9          2
# 11977        2476      2277      173             302        102
# 11978        1345      1280        8              57         39
# 11979         193       178        0               6         11
# 11980        1097      1033       26             182         63
# 11981        1825      1756       40              70         88
# 11982         540       486       36              94         38
# 11983         269       192       24              38         33
# 11984        1474      1423        6              30         44
# 11985        1626      1404       11             311         95
# 11986        4525      4253      102             322        326
# 11987         403       356        6              18         34
# 11988         278       265        0               9         11
# 11989         245       193       14              23         17
# 11990        2345      2270       45             136         61
# 11991         394       332       30              83         87
# 11992        1500      1439       22             217         33
# 11993         661       620        7              31         23
# 11994         121       117        0               2          2
# 11995        2667      2363      140             397        158
# 11996         102        92        1               6          7
# 11997         995       879       45              74         55
# 11998         402       339       15              52         24
# 11999        3308      2973       42             209        188
#
#             ...        nr_longwords  nr_stopwords  nr_words  avg_length_np  \
# 0           ...                12.0          27.0      50.0       7.857143
# 1           ...                62.0          51.0     212.0      11.446809
# 2           ...               113.0         167.0     396.0      10.201835
# 3           ...               129.0         198.0     600.0       9.891192
# 4           ...                64.0          39.0     137.0      15.307692
# 5           ...                 7.0          12.0      24.0       9.125000
# 6           ...               103.0         209.0     416.0      10.191304
# 7           ...               134.0         234.0     498.0       7.656627
# 8           ...                 8.0          25.0      50.0       7.714286
# 9           ...                52.0          44.0     183.0      11.745455
# 10          ...                25.0          49.0      88.0       7.714286
# 11          ...               108.0          24.0     222.0      18.765625
# 12          ...                 9.0          11.0      24.0      11.857143
# 13          ...               171.0         116.0     413.0       8.308411
# 14          ...                43.0          65.0     177.0       8.070423
# 15          ...                15.0          13.0      37.0      12.000000
# 16          ...                52.0          29.0     112.0      11.020833
# 17          ...                36.0          75.0     173.0       7.758621
# 18          ...               139.0          98.0     365.0      12.456693
# 19          ...                51.0          21.0     117.0      13.266667
# 20          ...                64.0          61.0     184.0      15.040000
# 21          ...                41.0          38.0     103.0      10.714286
# 22          ...                23.0          29.0      65.0      10.210526
# 23          ...               116.0         164.0     359.0      10.592920
# 24          ...                87.0         115.0     281.0      13.132353
# 25          ...                26.0          48.0     124.0       7.901961
# 26          ...                17.0           9.0      41.0      10.666667
# 27          ...                 2.0          15.0      25.0       6.500000
# 28          ...                31.0          45.0      93.0       8.709677
# 29          ...                62.0         121.0     275.0       7.398148
# ...         ...                 ...           ...       ...            ...
# 11970       ...                97.0          83.0     263.0      12.483871
# 11971       ...               186.0         312.0     726.0       9.815668
# 11972       ...                26.0          36.0     107.0      10.744186
# 11973       ...               497.0         461.0    1464.0      19.490775
# 11974       ...                40.0          62.0     132.0       9.837838
# 11975       ...                40.0          69.0     161.0      10.225000
# 11976       ...                 8.0           0.0      16.0      10.300000
# 11977       ...               107.0         217.0     473.0       9.701149
# 11978       ...               101.0         118.0     253.0      13.446154
# 11979       ...                15.0          17.0      36.0      10.250000
# 11980       ...                67.0          83.0     200.0      11.096774
# 11981       ...               115.0         206.0     378.0      10.457143
# 11982       ...                29.0          51.0     118.0      10.676471
# 11983       ...                19.0          12.0      61.0      12.947368
# 11984       ...                92.0         168.0     326.0      11.038462
# 11985       ...               122.0          72.0     229.0      12.422680
# 11986       ...               281.0         323.0     853.0      12.023346
# 11987       ...                35.0          12.0      63.0      16.250000
# 11988       ...                15.0          30.0      62.0      11.200000
# 11989       ...                12.0          16.0      51.0      11.294118
# 11990       ...               158.0         262.0     499.0      10.042254
# 11991       ...                29.0          16.0      69.0      10.590909
# 11992       ...                79.0         204.0     352.0       7.571429
# 11993       ...                47.0          57.0     137.0      14.468750
# 11994       ...                 6.0          13.0      24.0       9.000000
# 11995       ...               180.0         173.0     472.0      11.282051
# 11996       ...                 6.0           7.0      18.0      11.166667
# 11997       ...                63.0          73.0     197.0      11.790323
# 11998       ...                27.0          20.0      61.0      12.700000
# 11999       ...               186.0         315.0     699.0      11.291262
#
#        nr_function  nr_pos  nr_named_entity  nr_neg_word  nr_positive_word  \
# 0             21.0    14.0               15            0                 0
# 1             44.0    16.0              193            0                 1
# 2            132.0    17.0              151            0                 2
# 3            174.0    16.0              342            0                 0
# 4             36.0    15.0               80            0                 0
# 5              6.0    11.0                5            0                 0
# 6            158.0    16.0              137            2                 1
# 7            178.0    16.0              128            5                 1
# 8             20.0    13.0               10            0                 0
# 9             36.0    16.0              110            0                 0
# 10            34.0    13.0                9            0                 1
# 11            23.0    15.0              198            0                 0
# 12            10.0    13.0                2            0                 0
# 13            91.0    17.0              270            0                 1
# 14            48.0    15.0               62            0                 0
# 15             8.0     8.0               25            0                 0
# 16            34.0    15.0               77            0                 0
# 17            58.0    16.0               48            0                 3
# 18            75.0    16.0              220            0                 1
# 19            23.0    14.0               89            0                 0
# 20            49.0    16.0              106            0                 0
# 21            32.0    16.0               31            0                 2
# 22            21.0    15.0               19            0                 0
# 23           140.0    16.0               80            5                 2
# 24            69.0    16.0               98            3                 2
# 25            40.0    17.0               74            0                 0
# 26            13.0    13.0               32            0                 0
# 27             8.0    13.0                4            0                 0
# 28            36.0    15.0               21            0                 0
# 29           100.0    16.0               91            0                 1
# ...            ...     ...              ...          ...               ...
# 11970         76.0    17.0              132            0                 0
# 11971        234.0    16.0              262            0                 0
# 11972         33.0    16.0               55            0                 0
# 11973        436.0    17.0              870           10                24
# 11974         41.0    16.0               33            0                 0
# 11975         53.0    15.0               30            0                 0
# 11976          0.0     4.0               13            0                 0
# 11977        165.0    17.0              103            1                 2
# 11978         84.0    14.0               63            0                 0
# 11979         14.0    13.0               11            0                 0
# 11980         74.0    17.0               98            0                 0
# 11981        152.0    16.0               71            1                 1
# 11982         42.0    15.0               39            0                 0
# 11983         12.0    13.0               32            0                 0
# 11984        128.0    14.0               63            0                 3
# 11985         60.0    17.0              105            0                 1
# 11986        281.0    16.0              360            8                 1
# 11987         10.0    11.0               41            0                 0
# 11988         29.0    13.0               13            0                 1
# 11989         12.0    14.0               32            0                 0
# 11990        178.0    16.0              104            2                 0
# 11991         16.0    14.0               40            0                 1
# 11992        155.0    16.0               46            1                 0
# 11993         37.0    17.0               27            0                 0
# 11994          7.0    10.0                1            0                 1
# 11995        155.0    17.0              232            0                 0
# 11996          8.0    12.0                3            0                 0
# 11997         62.0    16.0               96            0                 0
# 11998         16.0    16.0               39            0                 0
# 11999        226.0    17.0              163            0                 0
#
#        score_semantic
# 0              0.0258
# 1              0.9020
# 2              0.9634
# 3              0.9764
# 4              0.9360
# 5              0.0516
# 6              0.9906
# 7             -0.9101
# 8              0.7783
# 9              0.6504
# 10             0.9485
# 11             0.9623
# 12             0.3182
# 13             0.9250
# 14             0.9223
# 15             0.0000
# 16             0.7430
# 17             0.9662
# 18             0.2885
# 19             0.9690
# 20             0.8999
# 21             0.9741
# 22             0.9652
# 23             0.9634
# 24             0.8685
# 25             0.8074
# 26             0.7964
# 27             0.0000
# 28             0.9186
# 29             0.9906
# ...               ...
# 11970          0.9818
# 11971          0.9919
# 11972          0.2309
# 11973          0.9403
# 11974          0.5609
# 11975          0.8908
# 11976          0.0000
# 11977          0.9877
# 11978          0.9735
# 11979          0.8519
# 11980          0.9799
# 11981          0.9192
# 11982          0.5994
# 11983          0.8668
# 11984          0.8946
# 11985          0.9616
# 11986         -0.9904
# 11987          0.9382
# 11988          0.8271
# 11989          0.8106
# 11990          0.9390
# 11991          0.9842
# 11992          0.9829
# 11993          0.9231
# 11994          0.6440
# 11995          0.9888
# 11996          0.3612
# 11997          0.9343
# 11998          0.8299
# 11999          0.9947
#
# [12000 rows x 32 columns]>

# %% [markdown]
# ## Split training set and test set

# %% [markdown]
# ## use sklearn split

# %%
train,test= train_test_split(df_1000_12.index,test_size=0.2, random_state=42) # split the data using a 80/20 ratio

# return dataframe train
df_1000_12.iloc[train]
# Out:
#        user  avg_nr_word_per_sent  nr_sents  std_nr_word_per_sent  nr_chars  \
# 9182     10             33.000000       1.0              0.000000       108
# 11091    12             14.000000       2.0              4.242641       133
# 6428      7             18.176471      17.0             13.366167      1350
# 288       1             29.400000      15.0             45.227678      1691
# 2626      3             15.833333       6.0              5.036533       335
# 8862      9             12.250000       4.0             13.744696       181
# 3684      4              8.307692      26.0              6.851390       775
# 7971      8             13.961039      77.0             10.511199      4421
# 6950      7             10.500000      14.0             11.305206       636
# 388       1             18.047619      21.0             12.878184      1695
# 836       1             31.117647      17.0             24.598990      2137
# 9023     10             14.877551      49.0             21.388892      3164
# 3181      4             18.421053      19.0             16.537217      1432
# 280       1              9.000000       2.0              7.071068       139
# 8113      9              9.250000      48.0              7.577964      1625
# 4459      5             11.000000       1.0              0.000000        45
# 6298      7              6.500000      18.0              7.106335       517
# 5860      6              1.000000       1.0              0.000000        67
# 1112      2             17.272727      11.0             12.993005       718
# 3798      4              7.882353      51.0              7.058745      2580
# 11183    12             10.413793      29.0              8.042375      1260
# 10041    11             11.520000      25.0              9.717338      1394
# 9854     10             18.508772      57.0             26.872797      4833
# 4768      5              8.725490      51.0              7.483524      1980
# 3421      4             10.166667      12.0              7.505553       494
# 8693      9              8.500000       4.0              7.593857       126
# 267       1             11.769231      26.0             11.559611      1532
# 1598      2             22.000000       1.0              0.000000        80
# 4929      5             12.000000      55.0              8.423952      2693
# 9563     10             17.322581      31.0             12.757709      2026
# ...     ...                   ...       ...                   ...       ...
# 9274     10             16.400000      15.0             10.041343       908
# 8666      9             14.750000       8.0              8.843884       408
# 11096    12             19.000000       3.0             14.730920       248
# 6396      7             29.111111      27.0             38.233426      3173
# 3385      4             10.800000      25.0              8.883505      1318
# 4555      5             20.000000       2.0             11.313708       162
# 1184      2            149.333333       6.0            341.881071      4367
# 6420      7             20.687500      48.0             14.924143      4036
# 5051      6             12.981481      54.0             12.344872      3281
# 5311      6             13.333333       6.0              8.869423       301
# 2433      3             12.971014      69.0              9.264053      3376
# 6949      7             16.500000      18.0             15.515647      1229
# 10583    11             19.000000       1.0              0.000000        59
# 769       1             19.384615      13.0              8.684646       874
# 1685      2             24.647059      34.0             17.694174      3484
# 8322      9             20.000000       6.0             10.862780       503
# 11111    12             10.000000       1.0              0.000000        37
# 11363    12             17.071429      14.0             20.416676      1008
# 11636    12             20.777778       9.0             17.569702       773
# 5578      6             11.040816      98.0             17.245898      3106
# 4426      5             10.333333       3.0              8.504901       112
# 466       1             13.163265      49.0              9.478807      2712
# 6265      7             15.000000       1.0              0.000000        71
# 5734      6             12.103774     106.0             12.821804      5807
# 11284    12             11.125000      16.0             12.235876       747
# 11964    12             19.826087      23.0             14.153869      1837
# 5191      6             19.833333       6.0             11.267949       501
# 5390      6              8.666667       9.0              7.483315       315
# 860       1              7.750000       4.0              7.320064        92
# 7270      8              9.000000      11.0              8.955445       442
#
#        nr_letters  nr_lower  nr_nums  nr_punctuation  nr_spaces  \
# 9182           98        93        0               3          7
# 11091         101        89       16               9          7
# 6428         1174      1045       24             102         50
# 288          1389       987       29             167        106
# 2626          297       278       12              12         14
# 8862          145       134       14               8         14
# 3684          546       471       50             144         35
# 7971         3851      3249      134             290        146
# 6950          478       395       34              90         34
# 388          1406      1276       24             115        150
# 836          1942      1755       28             106         61
# 9023         2328      2059      363             326        147
# 3181         1204      1038       56             131         41
# 280           104       103        8              21          6
# 8113         1383      1264       46             126         70
# 4459           40        34        3               1          1
# 6298          378       343       27              74         38
# 5860           50        48        6              11          0
# 1112          627       617       25              22         44
# 3798         1965      1745      105             430         80
# 11183         977       717       86             123         74
# 10041         781       635      143             396         74
# 9854         4141      2933       84             464        144
# 4768         1298      1204       56             163        463
# 3421          344       307       41              82         27
# 8693          114       110        4               4          4
# 267          1209       521       62             209         52
# 1598           74        68        0               5          1
# 4929         2050      1796      115             317        211
# 9563         1753      1501       69             108         96
# ...           ...       ...      ...             ...        ...
# 9274          730       651       57              57         64
# 8666          328       294       37              22         21
# 11096         232       225        0               4         12
# 6396         2753      2225       53             262        105
# 3385         1004       645       49              38        227
# 4555          153       144        0               3          6
# 1184         3224      3149       48            1002         93
# 6420         3544      3284      147             229        116
# 5051         2479      2318       72             649         81
# 5311          144       119       52              84         21
# 2433         2597      2220      176             347        256
# 6949         1008       862       28             114         79
# 10583          52        46        0               7          0
# 769           810       776        6              28         30
# 1685         3132      2928       64             159        129
# 8322          447       408       24              19         13
# 11111          35        33        0               2          0
# 11363         773       683       41             128         66
# 11636         713       665       10              19         31
# 5578         2362      2163       55             528        161
# 4426          104        95        0               5          3
# 466          2226      2034       83             232        171
# 6265           53        39        6               6          6
# 5734         4002      3467      673             794        338
# 11284         529       388       78             115         25
# 11964        1559      1398       48             163         67
# 5191          473       443        2              12         14
# 5390          199       162       24              69         23
# 860            79        73        0               4          9
# 7270          300       267       41              76         25
#
#             ...        nr_longwords  nr_stopwords  nr_words  avg_length_np  \
# 9182        ...                 5.0          11.0      25.0       7.111111
# 11091       ...                 8.0           2.0      14.0      25.000000
# 6428        ...                72.0          90.0     220.0      12.047619
# 288         ...                77.0          24.0     228.0      19.543478
# 2626        ...                18.0          34.0      69.0       9.666667
# 8862        ...                10.0          12.0      31.0      13.222222
# 3684        ...                30.0          36.0     107.0       9.100000
# 7971        ...               233.0         365.0     777.0      11.247934
# 6950        ...                27.0          27.0      89.0      16.192308
# 388         ...                92.0         117.0     274.0      12.333333
# 836         ...               159.0          96.0     355.0      12.310606
# 9023        ...               148.0          96.0     327.0      13.306931
# 3181        ...                79.0          94.0     232.0      12.844828
# 280         ...                 2.0           4.0      10.0      26.000000
# 8113        ...                81.0         111.0     302.0       8.750000
# 4459        ...                 4.0           1.0       7.0      13.333333
# 6298        ...                23.0          25.0      74.0      11.043478
# 5860        ...                 0.0           0.0       0.0       0.000000
# 1112        ...                40.0          71.0     138.0      10.687500
# 3798        ...                41.0          49.0     140.0      15.868852
# 11183       ...                56.0          45.0     165.0      14.423729
# 10041       ...                32.0          19.0     116.0      18.547619
# 9854        ...               248.0         197.0     588.0      18.952381
# 4768        ...                55.0         108.0     254.0       7.569767
# 3421        ...                13.0          29.0      78.0       8.346154
# 8693        ...                 9.0          12.0      26.0      10.625000
# 267         ...                51.0          13.0     130.0      22.653061
# 1598        ...                 5.0           7.0      16.0      12.000000
# 4929        ...               117.0         170.0     444.0      12.119048
# 9563        ...                98.0         147.0     360.0      11.508333
# ...         ...                 ...           ...       ...            ...
# 9274        ...                47.0          54.0     150.0      11.660377
# 8666        ...                15.0          25.0      70.0       9.590909
# 11096       ...                17.0          21.0      46.0      11.583333
# 6396        ...               159.0         140.0     494.0      16.145299
# 3385        ...                85.0          36.0     175.0      14.842105
# 4555        ...                11.0          16.0      33.0       9.100000
# 1184        ...                30.0          11.0      66.0      11.500000
# 6420        ...               236.0         283.0     654.0      12.000000
# 5051        ...                70.0          23.0     143.0      13.935065
# 5311        ...                 8.0           6.0      31.0      15.250000
# 2433        ...               170.0         241.0     583.0       9.894180
# 6949        ...                70.0          65.0     197.0      14.538462
# 10583       ...                 5.0           3.0      12.0       7.500000
# 769         ...                37.0         107.0     198.0       7.396552
# 1685        ...               221.0         214.0     610.0      13.656805
# 8322        ...                31.0          34.0      85.0      14.538462
# 11111       ...                 2.0           3.0       8.0       9.000000
# 11363       ...                42.0          59.0     146.0      12.577778
# 11636       ...                41.0          77.0     151.0       8.625000
# 5578        ...               131.0         196.0     459.0       8.842424
# 4426        ...                 8.0           9.0      23.0      10.375000
# 466         ...               134.0         187.0     441.0      11.343066
# 6265        ...                 3.0           1.0       9.0      10.250000
# 5734        ...               192.0         117.0     483.0      17.176796
# 11284       ...                30.0          19.0      83.0      11.702703
# 11964       ...                93.0         156.0     339.0      11.395604
# 5191        ...                35.0          42.0      95.0      13.300000
# 5390        ...                11.0          14.0      46.0       8.615385
# 860         ...                 3.0          11.0      21.0       7.400000
# 7270        ...                14.0          24.0      57.0       8.875000
#
#        nr_function  nr_pos  nr_named_entity  nr_neg_word  nr_positive_word  \
# 9182          10.0    12.0                6            0                 0
# 11091          2.0     9.0               13            0                 0
# 6428          73.0    16.0               63            0                 0
# 288           27.0    16.0              194            0                 2
# 2626          26.0    14.0               29            0                 0
# 8862           9.0    12.0               14            0                 0
# 3684          31.0    16.0               58            0                 0
# 7971         287.0    17.0              245            0                 1
# 6950          28.0    16.0               60            0                 1
# 388           91.0    16.0               92            0                 1
# 836           70.0    16.0              223            0                 4
# 9023          85.0    17.0              217            0                 2
# 3181          64.0    16.0               99            0                 1
# 280            4.0    10.0                2            0                 0
# 8113         116.0    16.0              119            0                 4
# 4459           2.0     7.0                3            0                 0
# 6298          23.0    16.0               22            0                 0
# 5860           0.0     1.0                0            0                 0
# 1112          44.0    14.0               37            5                 0
# 3798          45.0    16.0              129            0                 0
# 11183         39.0    16.0              110            0                 0
# 10041         22.0    12.0               93            0                 0
# 9854         147.0    17.0              332            1                 0
# 4768          86.0    16.0               81            0                 0
# 3421          26.0    16.0               34            0                 0
# 8693          10.0    12.0                3            0                 0
# 267           14.0    12.0              166            0                 0
# 1598           7.0    11.0                3            0                 0
# 4929         140.0    16.0              146            0                 0
# 9563         117.0    16.0              155            0                 0
# ...            ...     ...              ...          ...               ...
# 9274          53.0    16.0               64            0                 1
# 8666          19.0    16.0               34            0                 0
# 11096         14.0    14.0                8            0                 3
# 6396         106.0    16.0              317            1                 1
# 3385          43.0    16.0               83            0                 0
# 4555           9.0    14.0               10            0                 0
# 1184          15.0    15.0              158            0                 0
# 6420         217.0    17.0              245            1                 2
# 5051          23.0    17.0              175            0                 1
# 5311           6.0    12.0               28            0                 0
# 2433         196.0    16.0              265            0                 0
# 6949          53.0    15.0               87            0                 0
# 10583          3.0     6.0                0            0                 0
# 769           82.0    15.0               37            0                 7
# 1685         196.0    15.0              229            6                 3
# 8322          28.0    16.0               40            0                 0
# 11111          1.0     6.0                1            0                 0
# 11363         48.0    17.0               58            1                 0
# 11636         65.0    15.0               21            0                 0
# 5578         165.0    16.0              249            1                 2
# 4426           5.0    10.0                8            0                 0
# 466          154.0    17.0              171            0                 6
# 6265           1.0     6.0                6            0                 0
# 5734         106.0    17.0              454            1                 4
# 11284         18.0    14.0               86            0                 0
# 11964        118.0    15.0               97            0                 0
# 5191          30.0    14.0               25            0                 0
# 5390          16.0    13.0               29            0                 0
# 860            8.0    13.0                3            0                 0
# 7270          19.0    17.0               36            0                 1
#
#        score_semantic
# 9182           0.7003
# 11091          0.5267
# 6428           0.9487
# 288            0.7345
# 2626           0.8338
# 8862           0.8020
# 3684          -0.7942
# 7971           0.0547
# 6950           0.8176
# 388            0.8425
# 836            0.9841
# 9023           0.9920
# 3181           0.9467
# 280            0.3182
# 8113           0.9789
# 4459           0.6486
# 6298           0.7579
# 5860           0.0000
# 1112          -0.9912
# 3798           0.7935
# 11183          0.6705
# 10041          0.7404
# 9854           0.9886
# 4768           0.9038
# 3421          -0.5255
# 8693           0.4215
# 267            0.0000
# 1598          -0.2960
# 4929           0.9637
# 9563           0.9969
# ...               ...
# 9274           0.9681
# 8666           0.9035
# 11096          0.9670
# 6396           0.9712
# 3385           0.9075
# 4555           0.6705
# 1184           0.7717
# 6420           0.9668
# 5051           0.6966
# 5311           0.0000
# 2433           0.9576
# 6949           0.8176
# 10583          0.2695
# 769            0.9945
# 1685          -0.8900
# 8322           0.5574
# 11111          0.0000
# 11363          0.0387
# 11636          0.9455
# 5578           0.9910
# 4426           0.7500
# 466            0.9984
# 6265           0.0000
# 5734           0.9934
# 11284          0.7906
# 11964          0.9517
# 5191           0.6808
# 5390           0.3182
# 860            0.3802
# 7270           0.9485
#
# [9600 rows x 32 columns]

# %%
train_df = df_1000_12.iloc[train]
test_df = df_1000_12.iloc[test]

# %%
print (train_df.shape)
print (test_df.shape)
# Out:
# (9600, 32)
# (2400, 32)

# %% [markdown]
# ## Present the statistics to the user by means of visualization

# %%
#correlation matrix
corrmat = train_df.corr()
f, ax = plt.subplots(figsize=(12, 9))
sns.heatmap(corrmat, vmax=.8, square=True);

# %%
# correlation matrix with top k features
k = 10 
cols = corrmat.nlargest(k, 'user')['user'].index
cm = np.corrcoef(train_df[cols].values.T)
sns.set(font_scale=1.25)
hm = sns.heatmap(cm, cbar=True, annot=True, square=True, fmt='.2f', annot_kws={'size': 10}, yticklabels=cols.values, xticklabels=cols.values)
plt.show()

# %%
g = sns.FacetGrid(train_df, col='user')

g.map(plt.hist, 'avg_nr_word_per_sent', bins=20)

# %%
g = sns.FacetGrid(train_df, col='user')

g.map(plt.hist, 'nr_colons', bins=20)

# %%
train_df.describe()
# Out:
#               user  avg_nr_word_per_sent     nr_sents  std_nr_word_per_sent  \
# count  9600.000000           9600.000000  9600.000000           9600.000000
# mean      6.515625             14.945759    23.396250             11.651595
# std       3.450567              6.779188    54.945547              9.171703
# min       1.000000              1.000000     1.000000              0.000000
# 25%       4.000000             10.582237     5.000000              7.287197
# 50%       7.000000             13.816498    13.000000             10.353781
# 75%      10.000000             17.960129    26.000000             14.247607
# max      12.000000            149.333333  2055.000000            341.881071
#
#             nr_chars     nr_letters       nr_lower      nr_nums  \
# count    9600.000000    9600.000000    9600.000000  9600.000000
# mean     1476.110625    1216.362083    1086.572187    54.390521
# std      4437.267091    3760.437372    3502.756023   188.835165
# min         3.000000       0.000000       0.000000     0.000000
# 25%       270.000000     216.000000     188.000000     7.000000
# 50%       690.000000     550.000000     479.000000    26.000000
# 75%      1515.250000    1229.000000    1076.000000    55.000000
# max    184911.000000  158282.000000  148497.000000  8210.000000
#
#        nr_punctuation     nr_spaces       ...        nr_longwords  \
# count     9600.000000   9600.000000       ...         9600.000000
# mean       122.909167     82.448854       ...           76.920312
# std        363.126576    423.999522       ...          251.757032
# min          0.000000      0.000000       ...            0.000000
# 25%         13.000000     13.000000       ...           12.000000
# 50%         49.000000     36.000000       ...           33.000000
# 75%        128.250000     79.000000       ...           75.000000
# max      12217.000000  35618.000000       ...        10249.000000
#
#        nr_stopwords      nr_words  avg_length_np  nr_function       nr_pos  \
# count   9600.000000   9600.000000    9600.000000  9600.000000  9600.000000
# mean      87.560833    229.710417      11.180116    71.549479    14.192396
# std      262.000326    665.316313       4.072223   210.341763     2.985775
# min        0.000000      0.000000       0.000000     0.000000     1.000000
# 25%       15.000000     44.000000       8.908741    13.000000    13.000000
# 50%       39.000000    109.000000      10.885165    33.000000    15.000000
# 75%       92.000000    238.000000      13.000000    75.000000    16.000000
# max    10268.000000  25833.000000     163.000000  8412.000000    17.000000
#
#        nr_named_entity  nr_neg_word  nr_positive_word  score_semantic
# count      9600.000000  9600.000000       9600.000000     9600.000000
# mean         94.759583     0.415208          0.847604        0.615985
# std         278.456568     2.499275          2.834168        0.447568
# min           0.000000     0.000000          0.000000       -0.999500
# 25%          16.000000     0.000000          0.000000        0.400975
# 50%          42.000000     0.000000          0.000000        0.812600
# 75%          98.000000     0.000000          1.000000        0.957125
# max       10732.000000    98.000000         78.000000        1.000000
#
# [8 rows x 32 columns]

# %% [markdown]
# ## Automatic classification

# %% [markdown]
# ### StandardScaler &  Minmax_scale

# %%
X = train_df.drop('user', axis=1)
y = train_df.user
sScaler = StandardScaler(copy=True, with_mean=True, with_std=True)

XScaled = minmax_scale((sScaler.fit_transform(X)), feature_range=(0, 1))
y_label = label_binarize(y, classes=list(range(1,13)))

# %%
X_test = test_df.drop('user', axis=1)
y_test = test_df.user
X_test_Scaled = minmax_scale((sScaler.fit_transform(X_test)), feature_range=(0, 1))
y_test_label = label_binarize(y_test, classes=list(range(1,13)))

# %% [markdown]
# ### Modling   with   Cross Validation

# %% [markdown]
# ### KNeighbors

# %%
clf = KNeighborsClassifier(n_neighbors = 10,algorithm='ball_tree')
scores = cross_val_score(clf, XScaled, y_label, cv=5, scoring='roc_auc')
print("roc_auc: %0.4f (+/- %0.4f)" % (scores.mean(), scores.std() * 2))
# Out:
# roc_auc: 0.6125 (+/- 0.0057)

# %%
clf = KNeighborsClassifier(n_neighbors = 50,algorithm='ball_tree')
scores = cross_val_score(clf, XScaled, y_label, cv=5, scoring='roc_auc')
print("roc_auc: %0.4f (+/- %0.4f)" % (scores.mean(), scores.std() * 2))
# Out:
# roc_auc: 0.6267 (+/- 0.0045)

# %%
clf = KNeighborsClassifier(n_neighbors = 500,weights ='distance')
scores = cross_val_score(clf, XScaled, y_label, cv=5, scoring='roc_auc')
print("roc_auc: %0.4f (+/- %0.4f)" % (scores.mean(), scores.std() * 2))
# Out:
# roc_auc: 0.6739 (+/- 0.0091)

# %%
clf = KNeighborsClassifier(n_neighbors = 100,weights ='distance')
scores = cross_val_score(clf, XScaled, y_label, cv=5, scoring='roc_auc')
print("roc_auc: %0.4f (+/- %0.4f)" % (scores.mean(), scores.std() * 2))
# Out:
# roc_auc: 0.6792 (+/- 0.0038)

# %% [markdown]
# ### Random Forest

# %%
clf = RandomForestClassifier(n_estimators=10) # random forest doesn't need scaler 
scores = cross_val_score(clf, X, y_label, cv=5, scoring='roc_auc')
print("roc_auc: %0.4f (+/- %0.4f)" % (scores.mean(), scores.std() * 2))
# Out:
# roc_auc: 0.6746 (+/- 0.0052)

# %%
clf = RandomForestClassifier(n_estimators=50) 
scores = cross_val_score(clf, X, y_label, cv=5, scoring='roc_auc')
print("roc_auc: %0.4f (+/- %0.4f)" % (scores.mean(), scores.std() * 2))
# Out:
# roc_auc: 0.7353 (+/- 0.0101)

# %%
clf = RandomForestClassifier(n_estimators=100) 
scores = cross_val_score(clf, X, y_label, cv=5, scoring='roc_auc')
print("roc_auc: %0.4f (+/- %0.4f)" % (scores.mean(), scores.std() * 2))
# Out:
# roc_auc: 0.7512 (+/- 0.0080)

# %% [markdown]
# ##  Use Random Forest for prediction

# %%
random_forest = RandomForestClassifier(n_estimators=100)
random_forest.fit(X, y)
Y_pred = random_forest.predict(X_test)
acc_random_forest = round(random_forest.score(X_test, y_test) * 100, 5)
acc_random_forest
# Out:
# 34.166670000000003

# %%
print(Y_pred[:10])
# Out:
# [ 9  6  5 10  2 10  6  8 11  9]

# %%
print(y_test[:10])
# Out:
# 1935     2
# 6494     7
# 1720     2
# 9120    10
# 360      1
# 9663    10
# 5277     6
# 8546     9
# 2221     3
# 4617     5
# Name: user, dtype: int64

# %%
knn = KNeighborsClassifier(n_neighbors = 100)
knn.fit(X, y)
Y_pred = knn.predict(X_test)
acc_knn = round(knn.score(X_test, y_test) * 100, 5)
acc_knn
# Out:
# 16.70833

# %%
l = random.sample(range(1,13),3)
train_df_3 = train_df.loc[train_df['user'].isin(l)]
test_df_3 = test_df.loc[test_df['user'].isin(l)]
print(l)
# Out:
# [7, 5, 8]

# %%
X_3 = train_df_3.drop('user', axis=1)
y_3 = train_df_3.user
sScaler = StandardScaler(copy=True, with_mean=True, with_std=True)

XScaled_3 = minmax_scale((sScaler.fit_transform(X_3)), feature_range=(0, 1))
# y = label_binarize(y, classes=list(range(1,13)))

# %%
X_test_3 = test_df_3.drop('user', axis=1)
y_test_3 = test_df_3.user
X_test_Scaled_3 = minmax_scale((sScaler.fit_transform(X_test_3)), feature_range=(0, 1))
# y_test = label_binarize(y_test, classes=list(range(1,13)))

# %%
random_forest = RandomForestClassifier(n_estimators=100)
random_forest.fit(X_3, y_3)
Y_pred = random_forest.predict_proba(X_test_3)
acc_random_forest = round(random_forest.score(X_test_3, y_test_3) * 100, 5)
acc_random_forest
# Out:
# 63.855420000000002

# %%
train_df['user'].value_counts()
# Out:
# 10    815
# 7     814
# 9     813
# 12    811
# 8     805
# 5     800
# 2     799
# 1     799
# 6     792
# 3     790
# 4     784
# 11    778
# Name: user, dtype: int64
